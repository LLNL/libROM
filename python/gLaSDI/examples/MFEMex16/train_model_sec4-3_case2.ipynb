# %%
import sys
sys.path.append("../../src")
import os
import datetime
import pandas as pd
import numpy as np
import numpy as np
from sindy_utils import library_size
from training import train_network
from error_utils import *
# import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()

from time import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import pickle 
import copy
import subprocess as sp
import matplotlib.patches as patches
import seaborn as sns
from copy import deepcopy
from matplotlib.ticker import FormatStrFormatter
# Out:
# WARNING:tensorflow:From /g/g92/he10/.conda/envs/tfvenv/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def get_gpu_memory():
  _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]

  ACCEPTABLE_AVAILABLE_MEMORY = 1024
  COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"
  memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
  memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
  return memory_free_values

device_list = tf.config.list_physical_devices('GPU')
free_mem = get_gpu_memory()
for i,gpu in enumerate(device_list):
    print(f'{gpu}: free memory: {free_mem[i]}')
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): free memory: 10934
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'): free memory: 16149
# PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'): free memory: 16149
# PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'): free memory: 16149

# %%
# specify which GPU to use
config = tf.ConfigProto(log_device_placement=False, gpu_options=tf.GPUOptions(allow_growth=True,visible_device_list='2'))

# %% [markdown]
# # Load data

# %%
# load training data
p1_train = np.linspace(4, 4.3, 2)
p2_train = np.linspace(1, 1.4, 2)
x0 = 0.5 # center coordinate of initial condition
num_train = p1_train.size * p2_train.size  # number of training cases
tstop = 0.3
dt = 5e-3
scaled = False # if data is normalized

if num_train > 1:
    train_data = pickle.load(open(f"./data/local{num_train}_tstop{tstop:.1f}c.p", "rb"))
else:
    train_data = pickle.load(open(f"./data/local{num_train}_p1{p1_train[0]:.1f}_p2{p2_train[0]:.1f}_tstop{tstop:.1f}.p", "rb"))
num_sindy = len(train_data['data'])
input_dim = train_data['data'][0]['x'].shape[1]

# testing data
# p1_test = p1_train
# p2_test = p2_train
p1_test = np.linspace(4, 4.3, 21)
p2_test = np.linspace(1, 1.4, 21)
num_test = p1_test.size * p2_test.size
if num_train > 1:
    test_data = pickle.load(open(f"./data/local{num_test}_tstop{tstop:.1f}c.p", "rb"))
else:
    test_data = pickle.load(open(f"./data/local{num_test}_p1{p1_test[0]:.1f}_p2{p2_test[0]:.1f}_tstop{tstop:.1f}.p", "rb"))

for i in range(num_sindy):
    print(f"case {i}: params: {train_data['param'][i]}, x shape: {train_data['data'][i]['x'].shape}")
# Out:
# case 0: params: [4.44 1.  ], x shape: (61, 1089)
# case 1: params: [4.44 2.  ], x shape: (61, 1089)
# case 2: params: [8.88 1.  ], x shape: (61, 1089)
# case 3: params: [8.88 2.  ], x shape: (61, 1089)

# %%
grid1, grid2 = np.meshgrid(p1_train, p2_train)
train_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))
grid1, grid2 = np.meshgrid(p1_test, p2_test)
test_param = np.hstack((grid1.flatten().reshape(-1,1), grid2.flatten().reshape(-1,1)))

train_idx = []
for i in range(num_test):
    for j in range(num_train):
        if np.abs(test_param[i,0]-train_param[j,0]) < 1e-8 and \
        np.abs(test_param[i,1]-train_param[j,1]) < 1e-8:
            train_idx.append(i)
print(train_idx)
# Out:
# [0, 1, 2, 3]

# %%
train_data_x = []
train_data_dx = []
for i in range(num_train):
    train_data_x.append(train_data['data'][i]['x'])
    train_data_dx.append(train_data['data'][i]['dx'])
train_data_x = np.vstack(train_data_x)
train_data_dx = np.vstack(train_data_dx)
print(train_data_x.shape, train_data_dx.shape)
# Out:
# (244, 1089) (244, 1089)

# %%
if scaled:
    x_min = train_data_x.min()
    train_data_x -= x_min
    x_max = train_data_x.max()
    train_data_x /= x_max

    dx_min = train_data_dx.min()
    train_data_dx -= dx_min
    dx_max = train_data_dx.max()
    train_data_dx /= dx_max
    
    for i in range(num_train):
        train_data['data'][i]['x'] = (train_data['data'][i]['x'] - x_min) / x_max
        train_data['data'][i]['dx'] = (train_data['data'][i]['dx'] - dx_min) / dx_max
    
    for i in range(num_test):
        test_data['data'][i]['x'] = (test_data['data'][i]['x'] - x_min) / x_max
        test_data['data'][i]['dx'] = (test_data['data'][i]['dx'] - dx_min) / dx_max
        
else:
    x_min = 0
    x_max = 1
    dx_min = 0
    dx_max = 1

# %% [markdown]
# # Set up model and training parameters

# %%
params = {}

params['seed'] = 1 # random seed
params['config'] = config
params['num_sindy'] = num_sindy
params['param'] = train_data['param']
params['train_idx'] = train_idx
params['input_dim'] = input_dim
params['latent_dim'] = 3
params['model_order'] = 1
params['poly_order'] = 1
params['include_sine'] = False
params['include_cosine'] = False
params['include_costant'] = True
params['library_dim'] = library_size(params['latent_dim'], params['poly_order'], 
                                     params['include_sine'], params['include_cosine'], 
                                     params['include_costant'])

# sequential thresholding parameters
params['sequential_thresholding'] = False
params['coefficient_threshold'] = 0.1
params['threshold_frequency'] = 500
params['coefficient_mask'] = np.ones((params['library_dim'], params['latent_dim']))
params['coefficient_initialization'] = 'constant'

# loss function weighting
params['loss_weight_decoder'] = 1.0
params['loss_weight_sindy_x'] = 1e-4
params['loss_weight_sindy_z'] = 1e-4
params['loss_weight_sindy_regularization'] = 0
params['diff'] = 'symb' # 'symb': symbolic diff (only for fully connected Autoencoder), 'auto': automatic diff
params['activation'] = 'sigmoid'
params['widths'] = [100]

# training parameters
params['epoch_size'] = train_data['data'][0]['x'].shape[0]
params['batch_size'] = train_data['data'][0]['x'].shape[0]
params['learning_rate'] = 5e-4

params['fig_path'] = os.getcwd() + '/fig/IC3c_nCase441_tstop0.3_ld3_p1_1e-4_lr5e-4_width100_nDI25_upEP1e5_resNS0.1/'
params['print_progress'] = True
params['print_frequency'] = 100
params['save_frequency'] = 100

# training time cutoffs
params['max_epochs'] = 3000000  # max number of training epochs
params['refinement_epochs'] = 0

# Greedy algorithm
params['update_epoch'] = 100000 # update training set for every 2000 epochs
params['tol'] = 0.001         # max error allowed in the parameter space
params['tol2'] = 2            # max relative error allowed in the parameter space
params['sindy_max'] = 25      # max number of local SINDys; if tolerance is used as a termination criterior, set it as None
params['convex_knn'] = 1      # the number nearest local SINDys used for convex interpolation during Greedy sampling
params['test_data'] = test_data # path of test data
params['test_param'] = np.hstack((p1_test.reshape(-1,1), p2_test.reshape(-1,1)))    # parameters of test data
params['num_test'] = num_test                     # number of test cases
params['coeff_exist'] = False                     # flag to indicate whether to initialize model coefficients with pescribed values
params['retrain'] = False     # whether to retrain the model

# Error indicator:
# 1: max relative error (if test data is available) 
# 2: residual norm (mean), 1D Burger's eqn
# 3: residual norm (mean), 2D Burger's eqn
# 4: MFEM example 16: Time dependent heat conduction
# 5: MFEM example 9: DG advection
params['err_type'] = 4                            
params['subsize'] = int(0.3 * num_test)           # initial number of random testing cases for Greedy search
params['subsize_max'] = 50                        # max percentage of random testing cases for Greedy search

# Adaptive approach for tol of error indicator:
# 'mean': use mean ratios between error indicator and max relative errors
# 'reg_mean': use linear regression line
# 'reg_max': use linear regression line shifted by std to upper bound
# 'reg_min': use linear regression line shifted by std to lower bound, more conservative
params['adaptive'] = 'reg_max'                      

# PDE parameters
params['pde'] = {}
params['pde']['exe_file'] = '../../src/ex16'
params['pde']['m_file'] = '../../src/ref-square.mesh'
params['pde']['u_file'] = './temp/ex16-u_pred1.gf'
params['pde']['res_file'] = "./temp/ex16-residual1.gf"
params['pde']['rl'] = 5
params['pde']['order'] = 1
params['pde']['ODEsolver'] = 1 # 1 - Backward Euler, 2 - SDIRK2, 3 - SDIRK3
params['pde']['tstop'] = tstop
params['pde']['dt'] = dt
params['pde']['height'] = p2_train[0]
params['pde']['width'] = p1_train[0]
# params['pde']['x1'] = p2_train[0]
# params['pde']['x2'] = p2_train[0]
params['pde']['x1'] = x0
params['pde']['x2'] = x0
params['pde']['res_ns'] = 0.1 # percentage of time steps for residual evaluation
params['pde']['Tmax_iter'] = 30 # max number of CG iterations in Tsolver


params['scaled'] = scaled # if data is normalized
params['x_min'] = x_min
params['x_max'] = x_max
params['dx_min'] = dx_min
params['dx_max'] = dx_max

# %%
if params['retrain']:
    save_name = 'burger_2022_03_08_08_37_10'
    params = pickle.load(open(params['fig_path'] + save_name + '_params.pkl', 'rb'))
    params['retrain'] = True
    params['coeff_exist'] = True  # flag to indicate whether to initialize model coefficients with pescribed values
    params['save_name'] = save_name
    params['max_epochs'] = 3000000
    params['update_epoch'] = 100000  # update training set for every 2000 epochs
    params['save_frequency'] = 5000
    
    for i in params['train_idx'][4:]:
        train_data['data'].append(test_data['data'][i])
        train_data['param'].append(test_data['param'][i])

# %% [markdown]
# # Run training experiments

# %%
num_experiments = 1
df = pd.DataFrame()
timer = []
timer.append(time())
for i in range(num_experiments):
    print('EXPERIMENT %d' % i)
    
    if not params['retrain']:
        params['save_name'] = 'burger_' + datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    tf.reset_default_graph()
    results_dict = train_network(train_data, params)
    df = df.append({**results_dict, **params}, ignore_index=True)
    
timer.append(time())
print(f'training time: {(timer[-1]-timer[0])/60:.2f} mins')
# Out:
# EXPERIMENT 0
# * Evaluating
#   Time: 0.00 s, Case: [4.44 1.  ], Tol: 0.00100, Max Error: -1.000000
# Epoch 0
#   train loss: 1.0182e+01, decoder: 1.0154e+01, sindy-x: 2.4880e+02, sindy-z: 2.6846e+01, sindy-reg: 4.0000
# Epoch 100
#   train loss: 1.5840e+00, decoder: 1.5507e+00, sindy-x: 2.4861e+02, sindy-z: 8.3866e+01, sindy-reg: 3.9382
# Epoch 200
#   train loss: 1.1455e+00, decoder: 1.1119e+00, sindy-x: 2.4737e+02, sindy-z: 8.9146e+01, sindy-reg: 3.9079
# Epoch 300
#   train loss: 7.1929e-01, decoder: 6.8159e-01, sindy-x: 2.4441e+02, sindy-z: 1.3255e+02, sindy-reg: 3.8599
# Epoch 400
#   train loss: 4.5472e-01, decoder: 4.0980e-01, sindy-x: 2.4204e+02, sindy-z: 2.0711e+02, sindy-reg: 3.7706
# Epoch 500
#   train loss: 3.1614e-01, decoder: 2.7179e-01, sindy-x: 2.4123e+02, sindy-z: 2.0229e+02, sindy-reg: 3.6750
# Epoch 600
#   train loss: 2.4752e-01, decoder: 2.0832e-01, sindy-x: 2.3977e+02, sindy-z: 1.5218e+02, sindy-reg: 3.6187
# Epoch 700
#   train loss: 2.1399e-01, decoder: 1.7786e-01, sindy-x: 2.3809e+02, sindy-z: 1.2322e+02, sindy-reg: 3.5880
# Epoch 800
#   train loss: 1.9527e-01, decoder: 1.6169e-01, sindy-x: 2.3597e+02, sindy-z: 9.9848e+01, sindy-reg: 3.5659
# Epoch 900
#   train loss: 1.8389e-01, decoder: 1.5222e-01, sindy-x: 2.3393e+02, sindy-z: 8.2804e+01, sindy-reg: 3.5463
# Epoch 1000
#   train loss: 1.7378e-01, decoder: 1.4350e-01, sindy-x: 2.3206e+02, sindy-z: 7.0778e+01, sindy-reg: 3.5270
# Epoch 1100
#   train loss: 1.7291e-01, decoder: 1.4353e-01, sindy-x: 2.3061e+02, sindy-z: 6.3236e+01, sindy-reg: 3.5079
# Epoch 1200
#   train loss: 1.6373e-01, decoder: 1.3520e-01, sindy-x: 2.2922e+02, sindy-z: 5.6047e+01, sindy-reg: 3.4900
# Epoch 1300
#   train loss: 1.5753e-01, decoder: 1.2968e-01, sindy-x: 2.2801e+02, sindy-z: 5.0547e+01, sindy-reg: 3.4734
# Epoch 1400
#   train loss: 1.5609e-01, decoder: 1.2872e-01, sindy-x: 2.2698e+02, sindy-z: 4.6663e+01, sindy-reg: 3.4571
# Epoch 1500
#   train loss: 1.5470e-01, decoder: 1.2784e-01, sindy-x: 2.2611e+02, sindy-z: 4.2411e+01, sindy-reg: 3.4418
# Epoch 1600
#   train loss: 1.4918e-01, decoder: 1.2266e-01, sindy-x: 2.2535e+02, sindy-z: 3.9903e+01, sindy-reg: 3.4273
# Epoch 1700
#   train loss: 1.4822e-01, decoder: 1.2227e-01, sindy-x: 2.2448e+02, sindy-z: 3.5012e+01, sindy-reg: 3.4138
# Epoch 1800
#   train loss: 1.4552e-01, decoder: 1.1975e-01, sindy-x: 2.2390e+02, sindy-z: 3.3802e+01, sindy-reg: 3.4010
# Epoch 1900
#   train loss: 1.4393e-01, decoder: 1.1841e-01, sindy-x: 2.2337e+02, sindy-z: 3.1789e+01, sindy-reg: 3.3888
# Epoch 2000
#   train loss: 1.4270e-01, decoder: 1.1741e-01, sindy-x: 2.2277e+02, sindy-z: 3.0208e+01, sindy-reg: 3.3776
# Epoch 2100
#   train loss: 1.4550e-01, decoder: 1.2032e-01, sindy-x: 2.2236e+02, sindy-z: 2.9361e+01, sindy-reg: 3.3673
# Epoch 2200
#   train loss: 1.4081e-01, decoder: 1.1601e-01, sindy-x: 2.2172e+02, sindy-z: 2.6334e+01, sindy-reg: 3.3584
# Epoch 2300
#   train loss: 1.4055e-01, decoder: 1.1588e-01, sindy-x: 2.2136e+02, sindy-z: 2.5357e+01, sindy-reg: 3.3487
# Epoch 2400
#   train loss: 1.3965e-01, decoder: 1.1517e-01, sindy-x: 2.2085e+02, sindy-z: 2.3947e+01, sindy-reg: 3.3419
# Epoch 2500
#   train loss: 1.3913e-01, decoder: 1.1484e-01, sindy-x: 2.2035e+02, sindy-z: 2.2539e+01, sindy-reg: 3.3419
# Epoch 2600
#   train loss: 1.3882e-01, decoder: 1.1463e-01, sindy-x: 2.1988e+02, sindy-z: 2.2060e+01, sindy-reg: 3.3494
# Epoch 2700
#   train loss: 1.3830e-01, decoder: 1.1432e-01, sindy-x: 2.1950e+02, sindy-z: 2.0233e+01, sindy-reg: 3.3573
# Epoch 2800
#   train loss: 1.3828e-01, decoder: 1.1450e-01, sindy-x: 2.1905e+02, sindy-z: 1.8685e+01, sindy-reg: 3.3657
# Epoch 2900
#   train loss: 1.3761e-01, decoder: 1.1392e-01, sindy-x: 2.1876e+02, sindy-z: 1.8205e+01, sindy-reg: 3.3741
# Epoch 3000
#   train loss: 1.3732e-01, decoder: 1.1375e-01, sindy-x: 2.1843e+02, sindy-z: 1.7353e+01, sindy-reg: 3.3828
# Epoch 3100
#   train loss: 1.3703e-01, decoder: 1.1358e-01, sindy-x: 2.1807e+02, sindy-z: 1.6369e+01, sindy-reg: 3.3917
# Epoch 3200
#   train loss: 1.3679e-01, decoder: 1.1343e-01, sindy-x: 2.1774e+02, sindy-z: 1.5794e+01, sindy-reg: 3.4007
# Epoch 3300
#   train loss: 1.3647e-01, decoder: 1.1323e-01, sindy-x: 2.1741e+02, sindy-z: 1.4929e+01, sindy-reg: 3.4096
# Epoch 3400
#   train loss: 1.3620e-01, decoder: 1.1307e-01, sindy-x: 2.1709e+02, sindy-z: 1.4206e+01, sindy-reg: 3.4184
# Epoch 3500
#   train loss: 1.3586e-01, decoder: 1.1281e-01, sindy-x: 2.1677e+02, sindy-z: 1.3750e+01, sindy-reg: 3.4269
# Epoch 3600
#   train loss: 1.3554e-01, decoder: 1.1256e-01, sindy-x: 2.1646e+02, sindy-z: 1.3363e+01, sindy-reg: 3.4351
# Epoch 3700
#   train loss: 1.3515e-01, decoder: 1.1225e-01, sindy-x: 2.1611e+02, sindy-z: 1.2903e+01, sindy-reg: 3.4429
# Epoch 3800
#   train loss: 1.3495e-01, decoder: 1.1218e-01, sindy-x: 2.1566e+02, sindy-z: 1.2037e+01, sindy-reg: 3.4505
# Epoch 3900
#   train loss: 1.3415e-01, decoder: 1.1136e-01, sindy-x: 2.1545e+02, sindy-z: 1.2453e+01, sindy-reg: 3.4573
# Epoch 4000
#   train loss: 1.3363e-01, decoder: 1.1095e-01, sindy-x: 2.1494e+02, sindy-z: 1.1808e+01, sindy-reg: 3.4640
# Epoch 4100
#   train loss: 1.3254e-01, decoder: 1.0982e-01, sindy-x: 2.1468e+02, sindy-z: 1.2495e+01, sindy-reg: 3.4695
# Epoch 4200
#   train loss: 1.4233e-01, decoder: 1.1930e-01, sindy-x: 2.1471e+02, sindy-z: 1.5524e+01, sindy-reg: 3.4747
# Epoch 4300
#   train loss: 1.2944e-01, decoder: 1.0675e-01, sindy-x: 2.1353e+02, sindy-z: 1.3399e+01, sindy-reg: 3.4790
# Epoch 4400
#   train loss: 1.2675e-01, decoder: 1.0399e-01, sindy-x: 2.1273e+02, sindy-z: 1.4806e+01, sindy-reg: 3.4887
# Epoch 4500
#   train loss: 1.2290e-01, decoder: 1.0009e-01, sindy-x: 2.1125e+02, sindy-z: 1.6837e+01, sindy-reg: 3.4970
# Epoch 4600
#   train loss: 1.1682e-01, decoder: 9.3886e-02, sindy-x: 2.0924e+02, sindy-z: 2.0121e+01, sindy-reg: 3.5030
# Epoch 4700
#   train loss: 1.0797e-01, decoder: 8.4938e-02, sindy-x: 2.0584e+02, sindy-z: 2.4446e+01, sindy-reg: 3.5061
# Epoch 4800
#   train loss: 9.5887e-02, decoder: 7.2869e-02, sindy-x: 2.0088e+02, sindy-z: 2.9306e+01, sindy-reg: 3.5055
# Epoch 4900
#   train loss: 8.3296e-02, decoder: 6.0492e-02, sindy-x: 1.9428e+02, sindy-z: 3.3768e+01, sindy-reg: 3.5088
# Epoch 5000
#   train loss: 6.9987e-02, decoder: 4.7882e-02, sindy-x: 1.8621e+02, sindy-z: 3.4838e+01, sindy-reg: 3.5207
# Epoch 5100
#   train loss: 5.8868e-02, decoder: 3.7780e-02, sindy-x: 1.7780e+02, sindy-z: 3.3078e+01, sindy-reg: 3.5423
# Epoch 5200
#   train loss: 5.2141e-02, decoder: 3.2111e-02, sindy-x: 1.7018e+02, sindy-z: 3.0117e+01, sindy-reg: 3.5763
# Epoch 5300
#   train loss: 4.6790e-02, decoder: 2.7903e-02, sindy-x: 1.6188e+02, sindy-z: 2.6995e+01, sindy-reg: 3.6177
# Epoch 5400
#   train loss: 4.2307e-02, decoder: 2.4471e-02, sindy-x: 1.5540e+02, sindy-z: 2.2961e+01, sindy-reg: 3.6623
# Epoch 5500
#   train loss: 4.3417e-02, decoder: 2.6174e-02, sindy-x: 1.4868e+02, sindy-z: 2.3750e+01, sindy-reg: 3.7086
# Epoch 5600
#   train loss: 3.6967e-02, decoder: 2.0784e-02, sindy-x: 1.4401e+02, sindy-z: 1.7821e+01, sindy-reg: 3.7639
# Epoch 5700
#   train loss: 3.6369e-02, decoder: 2.0764e-02, sindy-x: 1.4012e+02, sindy-z: 1.5929e+01, sindy-reg: 3.8181
# Epoch 5800
#   train loss: 4.0800e-02, decoder: 2.5396e-02, sindy-x: 1.3383e+02, sindy-z: 2.0204e+01, sindy-reg: 3.8722
# Epoch 5900
#   train loss: 3.2396e-02, decoder: 1.7775e-02, sindy-x: 1.3053e+02, sindy-z: 1.5684e+01, sindy-reg: 3.9256
# Epoch 6000
#   train loss: 3.1330e-02, decoder: 1.7559e-02, sindy-x: 1.2631e+02, sindy-z: 1.1408e+01, sindy-reg: 3.9766
# Epoch 6100
#   train loss: 2.8718e-02, decoder: 1.5551e-02, sindy-x: 1.2330e+02, sindy-z: 8.3677e+00, sindy-reg: 4.0230
# Epoch 6200
#   train loss: 4.0004e-02, decoder: 2.5975e-02, sindy-x: 1.2384e+02, sindy-z: 1.6454e+01, sindy-reg: 4.0669
# Epoch 6300
#   train loss: 2.6037e-02, decoder: 1.3739e-02, sindy-x: 1.1668e+02, sindy-z: 6.3085e+00, sindy-reg: 4.1072
# Epoch 6400
#   train loss: 2.4828e-02, decoder: 1.2908e-02, sindy-x: 1.1342e+02, sindy-z: 5.7779e+00, sindy-reg: 4.1439
# Epoch 6500
#   train loss: 3.1028e-02, decoder: 1.8666e-02, sindy-x: 1.0998e+02, sindy-z: 1.3638e+01, sindy-reg: 4.1766
# Epoch 6600
#   train loss: 2.2528e-02, decoder: 1.1308e-02, sindy-x: 1.0767e+02, sindy-z: 4.5254e+00, sindy-reg: 4.2060
# Epoch 6700
#   train loss: 2.1509e-02, decoder: 1.0483e-02, sindy-x: 1.0446e+02, sindy-z: 5.7971e+00, sindy-reg: 4.2320
# Epoch 6800
#   train loss: 2.0125e-02, decoder: 9.6368e-03, sindy-x: 1.0075e+02, sindy-z: 4.1358e+00, sindy-reg: 4.2557
# Epoch 6900
#   train loss: 1.9763e-02, decoder: 9.5168e-03, sindy-x: 9.7104e+01, sindy-z: 5.3579e+00, sindy-reg: 4.2768
# Epoch 7000
#   train loss: 1.8113e-02, decoder: 8.3761e-03, sindy-x: 9.2903e+01, sindy-z: 4.4668e+00, sindy-reg: 4.2974
# Epoch 7100
#   train loss: 1.8375e-02, decoder: 8.8631e-03, sindy-x: 8.9028e+01, sindy-z: 6.0931e+00, sindy-reg: 4.3160
# Epoch 7200
#   train loss: 1.6111e-02, decoder: 7.1972e-03, sindy-x: 8.5084e+01, sindy-z: 4.0580e+00, sindy-reg: 4.3334
# Epoch 7300
#   train loss: 1.5278e-02, decoder: 6.7676e-03, sindy-x: 8.1268e+01, sindy-z: 3.8335e+00, sindy-reg: 4.3498
# Epoch 7400
#   train loss: 1.4241e-02, decoder: 6.1250e-03, sindy-x: 7.7905e+01, sindy-z: 3.2542e+00, sindy-reg: 4.3665
# Epoch 7500
#   train loss: 1.3943e-02, decoder: 6.1422e-03, sindy-x: 7.4551e+01, sindy-z: 3.4602e+00, sindy-reg: 4.3830
# Epoch 7600
#   train loss: 1.2980e-02, decoder: 5.5430e-03, sindy-x: 7.1190e+01, sindy-z: 3.1766e+00, sindy-reg: 4.4008
# Epoch 7700
#   train loss: 1.2927e-02, decoder: 5.6941e-03, sindy-x: 6.8147e+01, sindy-z: 4.1809e+00, sindy-reg: 4.4191
# Epoch 7800
#   train loss: 1.1756e-02, decoder: 4.9507e-03, sindy-x: 6.5184e+01, sindy-z: 2.8669e+00, sindy-reg: 4.4375
# Epoch 7900
#   train loss: 1.1186e-02, decoder: 4.6733e-03, sindy-x: 6.2516e+01, sindy-z: 2.6153e+00, sindy-reg: 4.4562
# Epoch 8000
#   train loss: 1.0698e-02, decoder: 4.4542e-03, sindy-x: 6.0030e+01, sindy-z: 2.4035e+00, sindy-reg: 4.4749
# Epoch 8100
#   train loss: 1.0275e-02, decoder: 4.2646e-03, sindy-x: 5.7783e+01, sindy-z: 2.3156e+00, sindy-reg: 4.4913
# Epoch 8200
#   train loss: 9.8752e-03, decoder: 4.0600e-03, sindy-x: 5.5373e+01, sindy-z: 2.7791e+00, sindy-reg: 4.5120
# Epoch 8300
#   train loss: 9.3023e-03, decoder: 3.7744e-03, sindy-x: 5.3274e+01, sindy-z: 2.0046e+00, sindy-reg: 4.5280
# Epoch 8400
#   train loss: 9.0419e-03, decoder: 3.6461e-03, sindy-x: 5.1311e+01, sindy-z: 2.6472e+00, sindy-reg: 4.5440
# Epoch 8500
#   train loss: 1.1441e-02, decoder: 5.8563e-03, sindy-x: 4.9833e+01, sindy-z: 6.0103e+00, sindy-reg: 4.5602
# Epoch 8600
#   train loss: 8.2052e-03, decoder: 3.2305e-03, sindy-x: 4.6931e+01, sindy-z: 2.8165e+00, sindy-reg: 4.5765
# Epoch 8700
#   train loss: 7.5787e-03, decoder: 2.9267e-03, sindy-x: 4.4792e+01, sindy-z: 1.7285e+00, sindy-reg: 4.5887
# Epoch 8800
#   train loss: 8.3058e-03, decoder: 3.5415e-03, sindy-x: 4.3025e+01, sindy-z: 4.6177e+00, sindy-reg: 4.6001
# Epoch 8900
#   train loss: 7.3007e-03, decoder: 2.9850e-03, sindy-x: 4.0768e+01, sindy-z: 2.3887e+00, sindy-reg: 4.6137
# Epoch 9000
#   train loss: 6.4781e-03, decoder: 2.4689e-03, sindy-x: 3.8394e+01, sindy-z: 1.6975e+00, sindy-reg: 4.6263
# Epoch 9100
#   train loss: 5.9863e-03, decoder: 2.2368e-03, sindy-x: 3.6124e+01, sindy-z: 1.3709e+00, sindy-reg: 4.6388
# Epoch 9200
#   train loss: 5.6164e-03, decoder: 2.0921e-03, sindy-x: 3.3981e+01, sindy-z: 1.2624e+00, sindy-reg: 4.6520
# Epoch 9300
#   train loss: 5.2832e-03, decoder: 1.9801e-03, sindy-x: 3.1827e+01, sindy-z: 1.2043e+00, sindy-reg: 4.6656
# Epoch 9400
#   train loss: 5.3008e-03, decoder: 2.1397e-03, sindy-x: 2.9825e+01, sindy-z: 1.7866e+00, sindy-reg: 4.6793
# Epoch 9500
#   train loss: 5.6839e-03, decoder: 2.4203e-03, sindy-x: 2.8077e+01, sindy-z: 4.5593e+00, sindy-reg: 4.6909
# Epoch 9600
#   train loss: 4.7232e-03, decoder: 1.8749e-03, sindy-x: 2.6549e+01, sindy-z: 1.9334e+00, sindy-reg: 4.7010
# Epoch 9700
#   train loss: 4.3072e-03, decoder: 1.6352e-03, sindy-x: 2.5017e+01, sindy-z: 1.7035e+00, sindy-reg: 4.7113
# Epoch 9800
#   train loss: 1.9205e-02, decoder: 1.3404e-02, sindy-x: 2.8493e+01, sindy-z: 2.9517e+01, sindy-reg: 4.7222
# Epoch 9900
#   train loss: 3.8031e-03, decoder: 1.4890e-03, sindy-x: 2.2221e+01, sindy-z: 9.1998e-01, sindy-reg: 4.7274
# Epoch 10000
#   train loss: 5.8271e-03, decoder: 3.0876e-03, sindy-x: 2.1929e+01, sindy-z: 5.4672e+00, sindy-reg: 4.7351
# Epoch 10100
#   train loss: 3.7569e-03, decoder: 1.5267e-03, sindy-x: 2.0516e+01, sindy-z: 1.7858e+00, sindy-reg: 4.7377
# Epoch 10200
#   train loss: 4.4515e-03, decoder: 2.1654e-03, sindy-x: 1.9825e+01, sindy-z: 3.0359e+00, sindy-reg: 4.7400
# Epoch 10300
#   train loss: 3.2155e-03, decoder: 1.2868e-03, sindy-x: 1.8400e+01, sindy-z: 8.8638e-01, sindy-reg: 4.7473
# Epoch 10400
#   train loss: 3.4680e-03, decoder: 1.5365e-03, sindy-x: 1.7534e+01, sindy-z: 1.7809e+00, sindy-reg: 4.7491
# Epoch 10500
#   train loss: 5.2670e-03, decoder: 2.7248e-03, sindy-x: 1.8775e+01, sindy-z: 6.6472e+00, sindy-reg: 4.7497
# Epoch 10600
#   train loss: 3.3427e-03, decoder: 1.4751e-03, sindy-x: 1.6656e+01, sindy-z: 2.0207e+00, sindy-reg: 4.7579
# Epoch 10700
#   train loss: 5.6499e-03, decoder: 3.2732e-03, sindy-x: 1.6561e+01, sindy-z: 7.2065e+00, sindy-reg: 4.7599
# Epoch 10800
#   train loss: 3.4558e-03, decoder: 1.6705e-03, sindy-x: 1.5219e+01, sindy-z: 2.6337e+00, sindy-reg: 4.7621
# Epoch 10900
#   train loss: 2.6104e-03, decoder: 1.0806e-03, sindy-x: 1.4483e+01, sindy-z: 8.1508e-01, sindy-reg: 4.7637
# Epoch 11000
#   train loss: 2.5250e-03, decoder: 1.0514e-03, sindy-x: 1.4016e+01, sindy-z: 7.1913e-01, sindy-reg: 4.7635
# Epoch 11100
#   train loss: 3.2116e-03, decoder: 1.6037e-03, sindy-x: 1.3845e+01, sindy-z: 2.2342e+00, sindy-reg: 4.7660
# Epoch 11200
#   train loss: 2.5925e-03, decoder: 1.1143e-03, sindy-x: 1.3360e+01, sindy-z: 1.4216e+00, sindy-reg: 4.7658
# Epoch 11300
#   train loss: 2.3436e-03, decoder: 1.0065e-03, sindy-x: 1.2722e+01, sindy-z: 6.4963e-01, sindy-reg: 4.7673
# Epoch 11400
#   train loss: 2.2972e-03, decoder: 9.8693e-04, sindy-x: 1.2391e+01, sindy-z: 7.1212e-01, sindy-reg: 4.7677
# Epoch 11500
#   train loss: 3.5674e-03, decoder: 1.7191e-03, sindy-x: 1.3389e+01, sindy-z: 5.0935e+00, sindy-reg: 4.7667
# Epoch 11600
#   train loss: 2.1397e-03, decoder: 9.3843e-04, sindy-x: 1.1563e+01, sindy-z: 4.4964e-01, sindy-reg: 4.7725
# Epoch 11700
#   train loss: 2.4129e-03, decoder: 1.0975e-03, sindy-x: 1.1648e+01, sindy-z: 1.5056e+00, sindy-reg: 4.7684
# Epoch 11800
#   train loss: 2.0501e-03, decoder: 9.1452e-04, sindy-x: 1.0955e+01, sindy-z: 4.0093e-01, sindy-reg: 4.7726
# Epoch 11900
#   train loss: 4.7282e-03, decoder: 2.4898e-03, sindy-x: 1.3188e+01, sindy-z: 9.1964e+00, sindy-reg: 4.7711
# Epoch 12000
#   train loss: 1.9737e-03, decoder: 8.9437e-04, sindy-x: 1.0427e+01, sindy-z: 3.6633e-01, sindy-reg: 4.7763
# Epoch 12100
#   train loss: 1.9692e-03, decoder: 9.0136e-04, sindy-x: 1.0197e+01, sindy-z: 4.8114e-01, sindy-reg: 4.7745
# Epoch 12200
#   train loss: 1.9014e-03, decoder: 8.7397e-04, sindy-x: 9.9492e+00, sindy-z: 3.2542e-01, sindy-reg: 4.7791
# Epoch 12300
#   train loss: 2.0190e-03, decoder: 9.2107e-04, sindy-x: 9.9690e+00, sindy-z: 1.0104e+00, sindy-reg: 4.7801
# Epoch 12400
#   train loss: 1.8421e-03, decoder: 8.6037e-04, sindy-x: 9.5042e+00, sindy-z: 3.1326e-01, sindy-reg: 4.7850
# Epoch 12500
#   train loss: 1.8089e-03, decoder: 8.4722e-04, sindy-x: 9.3246e+00, sindy-z: 2.9250e-01, sindy-reg: 4.7845
# Epoch 12600
#   train loss: 1.8045e-03, decoder: 8.5342e-04, sindy-x: 9.1036e+00, sindy-z: 4.0677e-01, sindy-reg: 4.7872
# Epoch 12700
#   train loss: 1.8105e-03, decoder: 8.6694e-04, sindy-x: 9.0100e+00, sindy-z: 4.2545e-01, sindy-reg: 4.7868
# Epoch 12800
#   train loss: 1.7839e-03, decoder: 8.5493e-04, sindy-x: 8.8424e+00, sindy-z: 4.4678e-01, sindy-reg: 4.7922
# Epoch 12900
#   train loss: 2.0758e-03, decoder: 1.0492e-03, sindy-x: 8.6707e+00, sindy-z: 1.5962e+00, sindy-reg: 4.7939
# Epoch 13000
#   train loss: 2.3926e-03, decoder: 1.3107e-03, sindy-x: 8.5745e+00, sindy-z: 2.2453e+00, sindy-reg: 4.7958
# Epoch 13100
#   train loss: 1.8299e-03, decoder: 8.9406e-04, sindy-x: 8.3566e+00, sindy-z: 1.0021e+00, sindy-reg: 4.7981
# Epoch 13200
#   train loss: 2.1582e-03, decoder: 1.1676e-03, sindy-x: 8.2649e+00, sindy-z: 1.6410e+00, sindy-reg: 4.8006
# Epoch 13300
#   train loss: 2.0633e-03, decoder: 1.0202e-03, sindy-x: 8.3492e+00, sindy-z: 2.0814e+00, sindy-reg: 4.8030
# Epoch 13400
#   train loss: 2.8541e-03, decoder: 1.7153e-03, sindy-x: 8.2774e+00, sindy-z: 3.1107e+00, sindy-reg: 4.8064
# Epoch 13500
#   train loss: 5.5911e-03, decoder: 3.7179e-03, sindy-x: 9.6053e+00, sindy-z: 9.1260e+00, sindy-reg: 4.8087
# Epoch 13600
#   train loss: 2.8421e-03, decoder: 1.7100e-03, sindy-x: 8.1785e+00, sindy-z: 3.1425e+00, sindy-reg: 4.8115
# Epoch 13700
#   train loss: 1.7028e-03, decoder: 8.5558e-04, sindy-x: 7.2924e+00, sindy-z: 1.1799e+00, sindy-reg: 4.8135
# Epoch 13800
#   train loss: 6.3788e-03, decoder: 4.4301e-03, sindy-x: 9.0984e+00, sindy-z: 1.0389e+01, sindy-reg: 4.8169
# Epoch 13900
#   train loss: 2.3472e-03, decoder: 1.2971e-03, sindy-x: 7.4300e+00, sindy-z: 3.0712e+00, sindy-reg: 4.8202
# Epoch 14000
#   train loss: 1.9505e-03, decoder: 9.7431e-04, sindy-x: 7.4773e+00, sindy-z: 2.2848e+00, sindy-reg: 4.8220
# Epoch 14100
#   train loss: 1.6034e-03, decoder: 8.0658e-04, sindy-x: 6.8315e+00, sindy-z: 1.1370e+00, sindy-reg: 4.8236
# Epoch 14200
#   train loss: 1.5197e-03, decoder: 7.4757e-04, sindy-x: 6.9428e+00, sindy-z: 7.7888e-01, sindy-reg: 4.8250
# Epoch 14300
#   train loss: 1.3909e-03, decoder: 6.9870e-04, sindy-x: 6.6034e+00, sindy-z: 3.1876e-01, sindy-reg: 4.8312
# Epoch 14400
#   train loss: 1.3299e-03, decoder: 6.5969e-04, sindy-x: 6.4682e+00, sindy-z: 2.3426e-01, sindy-reg: 4.8342
# Epoch 14500
#   train loss: 1.3168e-03, decoder: 6.5456e-04, sindy-x: 6.3691e+00, sindy-z: 2.5341e-01, sindy-reg: 4.8342
# Epoch 14600
#   train loss: 1.5979e-03, decoder: 8.0638e-04, sindy-x: 6.2074e+00, sindy-z: 1.7074e+00, sindy-reg: 4.8355
# Epoch 14700
#   train loss: 1.2753e-03, decoder: 6.3224e-04, sindy-x: 6.1865e+00, sindy-z: 2.4406e-01, sindy-reg: 4.8400
# Epoch 14800
#   train loss: 1.7148e-03, decoder: 9.5616e-04, sindy-x: 6.2005e+00, sindy-z: 1.3859e+00, sindy-reg: 4.8426
# Epoch 14900
#   train loss: 1.7023e-03, decoder: 9.6512e-04, sindy-x: 6.1799e+00, sindy-z: 1.1915e+00, sindy-reg: 4.8447
# Epoch 15000
#   train loss: 1.2995e-03, decoder: 6.5790e-04, sindy-x: 5.8811e+00, sindy-z: 5.3476e-01, sindy-reg: 4.8462
# Epoch 15100
#   train loss: 1.3772e-03, decoder: 7.2573e-04, sindy-x: 5.9502e+00, sindy-z: 5.6411e-01, sindy-reg: 4.8477
# Epoch 15200
#   train loss: 1.2700e-03, decoder: 6.5340e-04, sindy-x: 5.7513e+00, sindy-z: 4.1421e-01, sindy-reg: 4.8513
# Epoch 15300
#   train loss: 1.6408e-03, decoder: 8.2780e-04, sindy-x: 5.7636e+00, sindy-z: 2.3666e+00, sindy-reg: 4.8526
# Epoch 15400
#   train loss: 3.1462e-03, decoder: 1.9051e-03, sindy-x: 7.0805e+00, sindy-z: 5.3308e+00, sindy-reg: 4.8549
# Epoch 15500
#   train loss: 2.4330e-03, decoder: 1.4520e-03, sindy-x: 6.3150e+00, sindy-z: 3.4947e+00, sindy-reg: 4.8547
# Epoch 15600
#   train loss: 1.1189e-03, decoder: 5.5356e-04, sindy-x: 5.4535e+00, sindy-z: 2.0014e-01, sindy-reg: 4.8600
# Epoch 15700
#   train loss: 1.1086e-03, decoder: 5.4575e-04, sindy-x: 5.4255e+00, sindy-z: 2.0329e-01, sindy-reg: 4.8605
# Epoch 15800
#   train loss: 1.1791e-03, decoder: 5.7913e-04, sindy-x: 5.5502e+00, sindy-z: 4.4942e-01, sindy-reg: 4.8623
# Epoch 15900
#   train loss: 1.2594e-03, decoder: 6.3261e-04, sindy-x: 5.2705e+00, sindy-z: 9.9771e-01, sindy-reg: 4.8633
# Epoch 16000
#   train loss: 1.0688e-03, decoder: 5.2757e-04, sindy-x: 5.2128e+00, sindy-z: 1.9954e-01, sindy-reg: 4.8663
# Epoch 16100
#   train loss: 1.0582e-03, decoder: 5.2044e-04, sindy-x: 5.1898e+00, sindy-z: 1.8785e-01, sindy-reg: 4.8692
# Epoch 16200
#   train loss: 1.0482e-03, decoder: 5.1473e-04, sindy-x: 5.1417e+00, sindy-z: 1.9288e-01, sindy-reg: 4.8683
# Epoch 16300
#   train loss: 1.2626e-03, decoder: 6.1829e-04, sindy-x: 5.0808e+00, sindy-z: 1.3624e+00, sindy-reg: 4.8701
# Epoch 16400
#   train loss: 1.1188e-03, decoder: 5.7089e-04, sindy-x: 5.1029e+00, sindy-z: 3.7660e-01, sindy-reg: 4.8714
# Epoch 16500
#   train loss: 1.1061e-03, decoder: 5.4032e-04, sindy-x: 4.9675e+00, sindy-z: 6.9069e-01, sindy-reg: 4.8741
# Epoch 16600
#   train loss: 1.0095e-03, decoder: 4.9478e-04, sindy-x: 4.9220e+00, sindy-z: 2.2534e-01, sindy-reg: 4.8751
# Epoch 16700
#   train loss: 1.1000e-03, decoder: 5.6510e-04, sindy-x: 4.9249e+00, sindy-z: 4.2382e-01, sindy-reg: 4.8778
# Epoch 16800
#   train loss: 1.5246e-03, decoder: 7.5880e-04, sindy-x: 5.0216e+00, sindy-z: 2.6363e+00, sindy-reg: 4.8780
# Epoch 16900
#   train loss: 1.4897e-03, decoder: 8.6074e-04, sindy-x: 5.0636e+00, sindy-z: 1.2256e+00, sindy-reg: 4.8784
# Epoch 17000
#   train loss: 1.3961e-03, decoder: 7.1139e-04, sindy-x: 5.1501e+00, sindy-z: 1.6970e+00, sindy-reg: 4.8806
# Epoch 17100
#   train loss: 9.8483e-04, decoder: 4.7714e-04, sindy-x: 4.8243e+00, sindy-z: 2.5252e-01, sindy-reg: 4.8821
# Epoch 17200
#   train loss: 9.8769e-04, decoder: 4.9009e-04, sindy-x: 4.7042e+00, sindy-z: 2.7181e-01, sindy-reg: 4.8842
# Epoch 17300
#   train loss: 9.3611e-04, decoder: 4.5242e-04, sindy-x: 4.6646e+00, sindy-z: 1.7227e-01, sindy-reg: 4.8863
# Epoch 17400
#   train loss: 9.2977e-04, decoder: 4.4886e-04, sindy-x: 4.6362e+00, sindy-z: 1.7284e-01, sindy-reg: 4.8866
# Epoch 17500
#   train loss: 3.4079e-03, decoder: 2.2208e-03, sindy-x: 6.2346e+00, sindy-z: 5.6359e+00, sindy-reg: 4.8890
# Epoch 17600
#   train loss: 1.3234e-03, decoder: 6.9919e-04, sindy-x: 4.9491e+00, sindy-z: 1.2934e+00, sindy-reg: 4.8901
# Epoch 17700
#   train loss: 9.2701e-04, decoder: 4.3909e-04, sindy-x: 4.5574e+00, sindy-z: 3.2180e-01, sindy-reg: 4.8909
# Epoch 17800
#   train loss: 9.7259e-04, decoder: 4.4204e-04, sindy-x: 4.6032e+00, sindy-z: 7.0238e-01, sindy-reg: 4.8905
# Epoch 17900
#   train loss: 3.1330e-03, decoder: 1.5760e-03, sindy-x: 6.6266e+00, sindy-z: 8.9432e+00, sindy-reg: 4.8945
# Epoch 18000
#   train loss: 1.1451e-03, decoder: 5.7800e-04, sindy-x: 4.4322e+00, sindy-z: 1.2390e+00, sindy-reg: 4.8955
# Epoch 18100
#   train loss: 9.9648e-04, decoder: 4.6886e-04, sindy-x: 4.5908e+00, sindy-z: 6.8547e-01, sindy-reg: 4.8969
# Epoch 18200
#   train loss: 8.6893e-04, decoder: 4.1452e-04, sindy-x: 4.3463e+00, sindy-z: 1.9778e-01, sindy-reg: 4.8965
# Epoch 18300
#   train loss: 8.6174e-04, decoder: 4.0583e-04, sindy-x: 4.3470e+00, sindy-z: 2.1203e-01, sindy-reg: 4.9004
# Epoch 18400
#   train loss: 8.5378e-04, decoder: 4.0422e-04, sindy-x: 4.3245e+00, sindy-z: 1.7111e-01, sindy-reg: 4.8993
# Epoch 18500
#   train loss: 9.5261e-04, decoder: 4.4102e-04, sindy-x: 4.4319e+00, sindy-z: 6.8398e-01, sindy-reg: 4.9029
# Epoch 18600
#   train loss: 8.7334e-04, decoder: 4.2408e-04, sindy-x: 4.1935e+00, sindy-z: 2.9907e-01, sindy-reg: 4.9041
# Epoch 18700
#   train loss: 8.5074e-04, decoder: 4.0831e-04, sindy-x: 4.1989e+00, sindy-z: 2.2537e-01, sindy-reg: 4.9043
# Epoch 18800
#   train loss: 2.4325e-03, decoder: 1.5532e-03, sindy-x: 4.9233e+00, sindy-z: 3.8700e+00, sindy-reg: 4.9065
# Epoch 18900
#   train loss: 8.2575e-04, decoder: 3.9021e-04, sindy-x: 4.1190e+00, sindy-z: 2.3640e-01, sindy-reg: 4.9086
# Epoch 19000
#   train loss: 8.0598e-04, decoder: 3.7557e-04, sindy-x: 4.0968e+00, sindy-z: 2.0730e-01, sindy-reg: 4.9103
# Epoch 19100
#   train loss: 8.1577e-04, decoder: 3.8989e-04, sindy-x: 4.0481e+00, sindy-z: 2.1071e-01, sindy-reg: 4.9102
# Epoch 19200
#   train loss: 1.0485e-03, decoder: 5.4622e-04, sindy-x: 4.1933e+00, sindy-z: 8.2991e-01, sindy-reg: 4.9111
# Epoch 19300
#   train loss: 9.2120e-04, decoder: 4.4150e-04, sindy-x: 4.1127e+00, sindy-z: 6.8429e-01, sindy-reg: 4.9136
# Epoch 19400
#   train loss: 1.5192e-03, decoder: 7.1511e-04, sindy-x: 4.1968e+00, sindy-z: 3.8438e+00, sindy-reg: 4.9144
# Epoch 19500
#   train loss: 9.6180e-04, decoder: 4.8289e-04, sindy-x: 4.0822e+00, sindy-z: 7.0695e-01, sindy-reg: 4.9168
# Epoch 19600
#   train loss: 1.2072e-03, decoder: 6.4833e-04, sindy-x: 4.1798e+00, sindy-z: 1.4092e+00, sindy-reg: 4.9181
# Epoch 19700
#   train loss: 8.9350e-04, decoder: 4.2148e-04, sindy-x: 3.8836e+00, sindy-z: 8.3667e-01, sindy-reg: 4.9188
# Epoch 19800
#   train loss: 7.4389e-04, decoder: 3.4353e-04, sindy-x: 3.8438e+00, sindy-z: 1.5982e-01, sindy-reg: 4.9209
# Epoch 19900
#   train loss: 7.4261e-04, decoder: 3.4397e-04, sindy-x: 3.7989e+00, sindy-z: 1.8747e-01, sindy-reg: 4.9226
# Epoch 20000
#   train loss: 7.5405e-04, decoder: 3.4562e-04, sindy-x: 3.7859e+00, sindy-z: 2.9842e-01, sindy-reg: 4.9240
# Epoch 20100
#   train loss: 7.3808e-04, decoder: 3.4224e-04, sindy-x: 3.7760e+00, sindy-z: 1.8233e-01, sindy-reg: 4.9231
# Epoch 20200
#   train loss: 1.0995e-03, decoder: 6.1302e-04, sindy-x: 3.8994e+00, sindy-z: 9.6515e-01, sindy-reg: 4.9267
# Epoch 20300
#   train loss: 1.0273e-03, decoder: 5.5894e-04, sindy-x: 3.8329e+00, sindy-z: 8.5079e-01, sindy-reg: 4.9265
# Epoch 20400
#   train loss: 1.7220e-03, decoder: 9.9967e-04, sindy-x: 4.2232e+00, sindy-z: 3.0002e+00, sindy-reg: 4.9289
# Epoch 20500
#   train loss: 7.2552e-04, decoder: 3.1953e-04, sindy-x: 3.6898e+00, sindy-z: 3.7004e-01, sindy-reg: 4.9304
# Epoch 20600
#   train loss: 7.0543e-04, decoder: 3.2034e-04, sindy-x: 3.6345e+00, sindy-z: 2.1646e-01, sindy-reg: 4.9297
# Epoch 20700
#   train loss: 6.8330e-04, decoder: 3.0890e-04, sindy-x: 3.6043e+00, sindy-z: 1.3967e-01, sindy-reg: 4.9337
# Epoch 20800
#   train loss: 6.8488e-04, decoder: 3.1140e-04, sindy-x: 3.5661e+00, sindy-z: 1.6866e-01, sindy-reg: 4.9352
# Epoch 20900
#   train loss: 6.7874e-04, decoder: 3.0747e-04, sindy-x: 3.5414e+00, sindy-z: 1.7127e-01, sindy-reg: 4.9350
# Epoch 21000
#   train loss: 3.2150e-03, decoder: 2.1419e-03, sindy-x: 4.9830e+00, sindy-z: 5.7476e+00, sindy-reg: 4.9356
# Epoch 21100
#   train loss: 6.7213e-04, decoder: 2.9909e-04, sindy-x: 3.5225e+00, sindy-z: 2.0798e-01, sindy-reg: 4.9377
# Epoch 21200
#   train loss: 1.1715e-03, decoder: 5.4389e-04, sindy-x: 4.0097e+00, sindy-z: 2.2664e+00, sindy-reg: 4.9400
# Epoch 21300
#   train loss: 8.9225e-04, decoder: 4.1271e-04, sindy-x: 3.5260e+00, sindy-z: 1.2694e+00, sindy-reg: 4.9408
# Epoch 21400
#   train loss: 7.6642e-04, decoder: 3.3807e-04, sindy-x: 3.6137e+00, sindy-z: 6.6977e-01, sindy-reg: 4.9418
# Epoch 21500
#   train loss: 6.4505e-04, decoder: 2.8304e-04, sindy-x: 3.4028e+00, sindy-z: 2.1726e-01, sindy-reg: 4.9428
# Epoch 21600
#   train loss: 6.5356e-04, decoder: 2.9268e-04, sindy-x: 3.3770e+00, sindy-z: 2.3186e-01, sindy-reg: 4.9447
# Epoch 21700
#   train loss: 6.7367e-04, decoder: 2.9330e-04, sindy-x: 3.4089e+00, sindy-z: 3.9480e-01, sindy-reg: 4.9432
# Epoch 21800
#   train loss: 8.2094e-04, decoder: 3.7175e-04, sindy-x: 3.3928e+00, sindy-z: 1.0990e+00, sindy-reg: 4.9470
# Epoch 21900
#   train loss: 9.4203e-04, decoder: 5.1903e-04, sindy-x: 3.4792e+00, sindy-z: 7.5075e-01, sindy-reg: 4.9480
# Epoch 22000
#   train loss: 7.1284e-04, decoder: 3.2110e-04, sindy-x: 3.2958e+00, sindy-z: 6.2162e-01, sindy-reg: 4.9488
# Epoch 22100
#   train loss: 1.9648e-03, decoder: 1.1723e-03, sindy-x: 4.4063e+00, sindy-z: 3.5191e+00, sindy-reg: 4.9508
# Epoch 22200
#   train loss: 5.9764e-04, decoder: 2.5980e-04, sindy-x: 3.2578e+00, sindy-z: 1.2059e-01, sindy-reg: 4.9519
# Epoch 22300
#   train loss: 6.2722e-04, decoder: 2.7409e-04, sindy-x: 3.2446e+00, sindy-z: 2.8666e-01, sindy-reg: 4.9534
# Epoch 22400
#   train loss: 7.2264e-04, decoder: 3.5786e-04, sindy-x: 3.2656e+00, sindy-z: 3.8223e-01, sindy-reg: 4.9523
# Epoch 22500
#   train loss: 5.9840e-04, decoder: 2.5577e-04, sindy-x: 3.2325e+00, sindy-z: 1.9375e-01, sindy-reg: 4.9557
# Epoch 22600
#   train loss: 5.8762e-04, decoder: 2.5212e-04, sindy-x: 3.2096e+00, sindy-z: 1.4539e-01, sindy-reg: 4.9550
# Epoch 22700
#   train loss: 6.9194e-04, decoder: 3.0679e-04, sindy-x: 3.1723e+00, sindy-z: 6.7922e-01, sindy-reg: 4.9578
# Epoch 22800
#   train loss: 5.6990e-04, decoder: 2.4490e-04, sindy-x: 3.1268e+00, sindy-z: 1.2323e-01, sindy-reg: 4.9586
# Epoch 22900
#   train loss: 5.8785e-04, decoder: 2.5614e-04, sindy-x: 3.0991e+00, sindy-z: 2.1798e-01, sindy-reg: 4.9598
# Epoch 23000
#   train loss: 5.8365e-04, decoder: 2.4360e-04, sindy-x: 3.1270e+00, sindy-z: 2.7347e-01, sindy-reg: 4.9583
# Epoch 23100
#   train loss: 5.5785e-04, decoder: 2.3652e-04, sindy-x: 3.0848e+00, sindy-z: 1.2848e-01, sindy-reg: 4.9623
# Epoch 23200
#   train loss: 7.1955e-03, decoder: 4.9491e-03, sindy-x: 6.7146e+00, sindy-z: 1.5749e+01, sindy-reg: 4.9629
# Epoch 23300
#   train loss: 5.4828e-04, decoder: 2.3230e-04, sindy-x: 3.0457e+00, sindy-z: 1.1417e-01, sindy-reg: 4.9639
# Epoch 23400
#   train loss: 5.4278e-04, decoder: 2.3002e-04, sindy-x: 3.0102e+00, sindy-z: 1.1740e-01, sindy-reg: 4.9651
# Epoch 23500
#   train loss: 5.4473e-04, decoder: 2.3016e-04, sindy-x: 3.0139e+00, sindy-z: 1.3183e-01, sindy-reg: 4.9654
# Epoch 23600
#   train loss: 5.3433e-04, decoder: 2.2492e-04, sindy-x: 2.9821e+00, sindy-z: 1.1197e-01, sindy-reg: 4.9671
# Epoch 23700
#   train loss: 6.1469e-04, decoder: 2.3931e-04, sindy-x: 3.0978e+00, sindy-z: 6.5602e-01, sindy-reg: 4.9687
# Epoch 23800
#   train loss: 3.4613e-03, decoder: 2.3849e-03, sindy-x: 4.5036e+00, sindy-z: 6.2604e+00, sindy-reg: 4.9708
# Epoch 23900
#   train loss: 5.2347e-04, decoder: 2.1886e-04, sindy-x: 2.9381e+00, sindy-z: 1.0791e-01, sindy-reg: 4.9700
# Epoch 24000
#   train loss: 6.6207e-04, decoder: 3.0720e-04, sindy-x: 2.9784e+00, sindy-z: 5.7024e-01, sindy-reg: 4.9715
# Epoch 24100
#   train loss: 5.2964e-04, decoder: 2.2502e-04, sindy-x: 2.9174e+00, sindy-z: 1.2883e-01, sindy-reg: 4.9715
# Epoch 24200
#   train loss: 1.0353e-03, decoder: 5.7399e-04, sindy-x: 3.1300e+00, sindy-z: 1.4833e+00, sindy-reg: 4.9716
# Epoch 24300
#   train loss: 5.1374e-04, decoder: 2.1381e-04, sindy-x: 2.8635e+00, sindy-z: 1.3576e-01, sindy-reg: 4.9751
# Epoch 24400
#   train loss: 5.1307e-04, decoder: 2.1267e-04, sindy-x: 2.8686e+00, sindy-z: 1.3549e-01, sindy-reg: 4.9758
# Epoch 24500
#   train loss: 5.1266e-04, decoder: 2.1512e-04, sindy-x: 2.8268e+00, sindy-z: 1.4864e-01, sindy-reg: 4.9761
# Epoch 24600
#   train loss: 8.6571e-04, decoder: 4.3096e-04, sindy-x: 3.1279e+00, sindy-z: 1.2197e+00, sindy-reg: 4.9752
# Epoch 24700
#   train loss: 4.9340e-04, decoder: 2.0301e-04, sindy-x: 2.7974e+00, sindy-z: 1.0658e-01, sindy-reg: 4.9787
# Epoch 24800
#   train loss: 6.0816e-04, decoder: 2.8372e-04, sindy-x: 2.8592e+00, sindy-z: 3.8513e-01, sindy-reg: 4.9797
# Epoch 24900
#   train loss: 6.5504e-04, decoder: 2.9140e-04, sindy-x: 2.8646e+00, sindy-z: 7.7185e-01, sindy-reg: 4.9792
# Epoch 25000
#   train loss: 8.0654e-04, decoder: 4.2813e-04, sindy-x: 2.8894e+00, sindy-z: 8.9462e-01, sindy-reg: 4.9824
# Epoch 25100
#   train loss: 8.8407e-04, decoder: 3.7698e-04, sindy-x: 3.1506e+00, sindy-z: 1.9203e+00, sindy-reg: 4.9823
# Epoch 25200
#   train loss: 6.1544e-04, decoder: 2.9470e-04, sindy-x: 2.7982e+00, sindy-z: 4.0918e-01, sindy-reg: 4.9810
# Epoch 25300
#   train loss: 4.8689e-04, decoder: 1.9558e-04, sindy-x: 2.7374e+00, sindy-z: 1.7567e-01, sindy-reg: 4.9844
# Epoch 25400
#   train loss: 1.5510e-03, decoder: 5.6922e-04, sindy-x: 3.5732e+00, sindy-z: 6.2450e+00, sindy-reg: 4.9813
# Epoch 25500
#   train loss: 4.6969e-04, decoder: 1.9069e-04, sindy-x: 2.6920e+00, sindy-z: 9.8078e-02, sindy-reg: 4.9849
# Epoch 25600
#   train loss: 4.6503e-04, decoder: 1.8874e-04, sindy-x: 2.6644e+00, sindy-z: 9.8467e-02, sindy-reg: 4.9864
# Epoch 25700
#   train loss: 4.6118e-04, decoder: 1.8648e-04, sindy-x: 2.6470e+00, sindy-z: 1.0003e-01, sindy-reg: 4.9891
# Epoch 25800
#   train loss: 5.3207e-04, decoder: 2.2212e-04, sindy-x: 2.7678e+00, sindy-z: 3.3168e-01, sindy-reg: 4.9841
# Epoch 25900
#   train loss: 4.5867e-04, decoder: 1.8550e-04, sindy-x: 2.6247e+00, sindy-z: 1.0697e-01, sindy-reg: 4.9889
# Epoch 26000
#   train loss: 4.5290e-04, decoder: 1.8253e-04, sindy-x: 2.6041e+00, sindy-z: 9.9631e-02, sindy-reg: 4.9912
# Epoch 26100
#   train loss: 8.9747e-04, decoder: 4.4513e-04, sindy-x: 3.0838e+00, sindy-z: 1.4396e+00, sindy-reg: 4.9929
# Epoch 26200
#   train loss: 1.5656e-03, decoder: 9.9498e-04, sindy-x: 3.4816e+00, sindy-z: 2.2248e+00, sindy-reg: 4.9938
# Epoch 26300
#   train loss: 4.4460e-04, decoder: 1.7850e-04, sindy-x: 2.5699e+00, sindy-z: 9.1097e-02, sindy-reg: 4.9937
# Epoch 26400
#   train loss: 5.4414e-04, decoder: 2.5244e-04, sindy-x: 2.6475e+00, sindy-z: 2.6953e-01, sindy-reg: 4.9948
# Epoch 26500
#   train loss: 4.6394e-04, decoder: 1.9202e-04, sindy-x: 2.5408e+00, sindy-z: 1.7844e-01, sindy-reg: 4.9949
# Epoch 26600
#   train loss: 6.8429e-04, decoder: 3.5690e-04, sindy-x: 2.6763e+00, sindy-z: 5.9765e-01, sindy-reg: 4.9954
# Epoch 26700
#   train loss: 8.5884e-04, decoder: 4.8286e-04, sindy-x: 2.8801e+00, sindy-z: 8.7976e-01, sindy-reg: 4.9975
# Epoch 26800
#   train loss: 4.3245e-04, decoder: 1.7330e-04, sindy-x: 2.4999e+00, sindy-z: 9.1572e-02, sindy-reg: 4.9971
# Epoch 26900
#   train loss: 2.1954e-03, decoder: 1.5160e-03, sindy-x: 3.6184e+00, sindy-z: 3.1762e+00, sindy-reg: 4.9991
# Epoch 27000
#   train loss: 4.2952e-04, decoder: 1.7076e-04, sindy-x: 2.4885e+00, sindy-z: 9.9100e-02, sindy-reg: 4.9985
# Epoch 27100
#   train loss: 6.6398e-04, decoder: 2.8246e-04, sindy-x: 2.7547e+00, sindy-z: 1.0605e+00, sindy-reg: 5.0006
# Epoch 27200
#   train loss: 5.7018e-04, decoder: 2.1960e-04, sindy-x: 2.4757e+00, sindy-z: 1.0301e+00, sindy-reg: 5.0006
# Epoch 27300
#   train loss: 4.3528e-04, decoder: 1.7063e-04, sindy-x: 2.4615e+00, sindy-z: 1.8505e-01, sindy-reg: 5.0017
# Epoch 27400
#   train loss: 4.5143e-04, decoder: 1.8940e-04, sindy-x: 2.4740e+00, sindy-z: 1.4630e-01, sindy-reg: 5.0032
# Epoch 27500
#   train loss: 4.2148e-03, decoder: 3.0421e-03, sindy-x: 4.7549e+00, sindy-z: 6.9729e+00, sindy-reg: 5.0037
# Epoch 27600
#   train loss: 4.9779e-04, decoder: 2.0198e-04, sindy-x: 2.4419e+00, sindy-z: 5.1615e-01, sindy-reg: 5.0035
# Epoch 27700
#   train loss: 2.8043e-03, decoder: 1.9050e-03, sindy-x: 3.8198e+00, sindy-z: 5.1727e+00, sindy-reg: 5.0049
# Epoch 27800
#   train loss: 4.0708e-04, decoder: 1.6105e-04, sindy-x: 2.3773e+00, sindy-z: 8.2975e-02, sindy-reg: 5.0066
# Epoch 27900
#   train loss: 4.2182e-04, decoder: 1.7167e-04, sindy-x: 2.3823e+00, sindy-z: 1.1916e-01, sindy-reg: 5.0052
# Epoch 28000
#   train loss: 4.7421e-04, decoder: 1.7708e-04, sindy-x: 2.3581e+00, sindy-z: 6.1320e-01, sindy-reg: 5.0074
# Epoch 28100
#   train loss: 4.5257e-04, decoder: 1.9517e-04, sindy-x: 2.3977e+00, sindy-z: 1.7621e-01, sindy-reg: 5.0065
# Epoch 28200
#   train loss: 4.9948e-04, decoder: 2.2906e-04, sindy-x: 2.3674e+00, sindy-z: 3.3682e-01, sindy-reg: 5.0092
# Epoch 28300
#   train loss: 3.9742e-04, decoder: 1.5688e-04, sindy-x: 2.3197e+00, sindy-z: 8.5599e-02, sindy-reg: 5.0098
# Epoch 28400
#   train loss: 3.9756e-04, decoder: 1.5751e-04, sindy-x: 2.3177e+00, sindy-z: 8.2786e-02, sindy-reg: 5.0094
# Epoch 28500
#   train loss: 4.1715e-04, decoder: 1.6993e-04, sindy-x: 2.3014e+00, sindy-z: 1.7078e-01, sindy-reg: 5.0117
# Epoch 28600
#   train loss: 7.3405e-04, decoder: 2.5326e-04, sindy-x: 2.3850e+00, sindy-z: 2.4229e+00, sindy-reg: 5.0115
# Epoch 28700
#   train loss: 5.4530e-04, decoder: 2.2522e-04, sindy-x: 2.3047e+00, sindy-z: 8.9607e-01, sindy-reg: 5.0117
# Epoch 28800
#   train loss: 4.4237e-04, decoder: 1.9049e-04, sindy-x: 2.2867e+00, sindy-z: 2.3217e-01, sindy-reg: 5.0126
# Epoch 28900
#   train loss: 4.7061e-04, decoder: 1.9149e-04, sindy-x: 2.3794e+00, sindy-z: 4.1180e-01, sindy-reg: 5.0123
# Epoch 29000
#   train loss: 9.0317e-04, decoder: 4.4295e-04, sindy-x: 2.3839e+00, sindy-z: 2.2183e+00, sindy-reg: 5.0131
# Epoch 29100
#   train loss: 8.2178e-04, decoder: 3.4920e-04, sindy-x: 2.3287e+00, sindy-z: 2.3971e+00, sindy-reg: 5.0141
# Epoch 29200
#   train loss: 4.8719e-04, decoder: 1.7543e-04, sindy-x: 2.4012e+00, sindy-z: 7.1639e-01, sindy-reg: 5.0139
# Epoch 29300
#   train loss: 3.8053e-04, decoder: 1.4899e-04, sindy-x: 2.2269e+00, sindy-z: 8.8413e-02, sindy-reg: 5.0163
# Epoch 29400
#   train loss: 3.8721e-04, decoder: 1.5237e-04, sindy-x: 2.2492e+00, sindy-z: 9.9132e-02, sindy-reg: 5.0168
# Epoch 29500
#   train loss: 3.7499e-04, decoder: 1.4616e-04, sindy-x: 2.2157e+00, sindy-z: 7.2567e-02, sindy-reg: 5.0181
# Epoch 29600
#   train loss: 8.1131e-04, decoder: 4.1495e-04, sindy-x: 2.6887e+00, sindy-z: 1.2750e+00, sindy-reg: 5.0186
# Epoch 29700
#   train loss: 3.7097e-04, decoder: 1.4520e-04, sindy-x: 2.1850e+00, sindy-z: 7.2662e-02, sindy-reg: 5.0190
# Epoch 29800
#   train loss: 3.2933e-03, decoder: 1.7486e-03, sindy-x: 3.5607e+00, sindy-z: 1.1887e+01, sindy-reg: 5.0174
# Epoch 29900
#   train loss: 3.6790e-04, decoder: 1.4383e-04, sindy-x: 2.1688e+00, sindy-z: 7.1869e-02, sindy-reg: 5.0202
# Epoch 30000
#   train loss: 5.4137e-04, decoder: 2.7438e-04, sindy-x: 2.3130e+00, sindy-z: 3.5683e-01, sindy-reg: 5.0207
# Epoch 30100
#   train loss: 3.6720e-04, decoder: 1.4419e-04, sindy-x: 2.1602e+00, sindy-z: 6.9925e-02, sindy-reg: 5.0188
# Epoch 30200
#   train loss: 9.1598e-04, decoder: 3.7472e-04, sindy-x: 2.5849e+00, sindy-z: 2.8277e+00, sindy-reg: 5.0204
# Epoch 30300
#   train loss: 3.6061e-04, decoder: 1.4068e-04, sindy-x: 2.1290e+00, sindy-z: 7.0251e-02, sindy-reg: 5.0222
# Epoch 30400
#   train loss: 4.3176e-04, decoder: 1.8650e-04, sindy-x: 2.1536e+00, sindy-z: 2.9899e-01, sindy-reg: 5.0221
# Epoch 30500
#   train loss: 5.1113e-04, decoder: 2.4383e-04, sindy-x: 2.1896e+00, sindy-z: 4.8342e-01, sindy-reg: 5.0227
# Epoch 30600
#   train loss: 3.9467e-04, decoder: 1.5138e-04, sindy-x: 2.1447e+00, sindy-z: 2.8817e-01, sindy-reg: 5.0223
# Epoch 30700
#   train loss: 2.1811e-03, decoder: 1.5119e-03, sindy-x: 3.0276e+00, sindy-z: 3.6647e+00, sindy-reg: 5.0239
# Epoch 30800
#   train loss: 3.6439e-04, decoder: 1.4474e-04, sindy-x: 2.0871e+00, sindy-z: 1.0940e-01, sindy-reg: 5.0245
# Epoch 30900
#   train loss: 4.1137e-04, decoder: 1.6941e-04, sindy-x: 2.1011e+00, sindy-z: 3.1847e-01, sindy-reg: 5.0241
# Epoch 31000
#   train loss: 4.5928e-04, decoder: 2.0073e-04, sindy-x: 2.1267e+00, sindy-z: 4.5875e-01, sindy-reg: 5.0221
# Epoch 31100
#   train loss: 3.5232e-04, decoder: 1.3620e-04, sindy-x: 2.0594e+00, sindy-z: 1.0187e-01, sindy-reg: 5.0253
# Epoch 31200
#   train loss: 6.2396e-04, decoder: 1.7448e-04, sindy-x: 2.2898e+00, sindy-z: 2.2049e+00, sindy-reg: 5.0245
# Epoch 31300
#   train loss: 4.0958e-04, decoder: 1.4502e-04, sindy-x: 2.1051e+00, sindy-z: 5.4046e-01, sindy-reg: 5.0265
# Epoch 31400
#   train loss: 3.5709e-04, decoder: 1.4328e-04, sindy-x: 2.0558e+00, sindy-z: 8.2276e-02, sindy-reg: 5.0253
# Epoch 31500
#   train loss: 3.4565e-04, decoder: 1.3427e-04, sindy-x: 2.0349e+00, sindy-z: 7.8840e-02, sindy-reg: 5.0273
# Epoch 31600
#   train loss: 4.0394e-04, decoder: 1.6406e-04, sindy-x: 2.0483e+00, sindy-z: 3.5047e-01, sindy-reg: 5.0269
# Epoch 31700
#   train loss: 6.1118e-04, decoder: 3.0301e-04, sindy-x: 2.1779e+00, sindy-z: 9.0382e-01, sindy-reg: 5.0269
# Epoch 31800
#   train loss: 7.0680e-04, decoder: 3.2947e-04, sindy-x: 2.1736e+00, sindy-z: 1.5996e+00, sindy-reg: 5.0282
# Epoch 31900
#   train loss: 8.2695e-04, decoder: 3.5935e-04, sindy-x: 2.5013e+00, sindy-z: 2.1747e+00, sindy-reg: 5.0284
# Epoch 32000
#   train loss: 5.7457e-04, decoder: 2.8941e-04, sindy-x: 2.1125e+00, sindy-z: 7.3909e-01, sindy-reg: 5.0283
# Epoch 32100
#   train loss: 4.3174e-04, decoder: 1.3902e-04, sindy-x: 2.0262e+00, sindy-z: 9.0112e-01, sindy-reg: 5.0291
# Epoch 32200
#   train loss: 4.0941e-04, decoder: 1.5403e-04, sindy-x: 2.0149e+00, sindy-z: 5.3891e-01, sindy-reg: 5.0281
# Epoch 32300
#   train loss: 3.8097e-04, decoder: 1.6367e-04, sindy-x: 1.9858e+00, sindy-z: 1.8728e-01, sindy-reg: 5.0304
# Epoch 32400
#   train loss: 6.0371e-04, decoder: 2.4534e-04, sindy-x: 2.0834e+00, sindy-z: 1.5003e+00, sindy-reg: 5.0296
# Epoch 32500
#   train loss: 8.2562e-03, decoder: 6.0709e-03, sindy-x: 5.9208e+00, sindy-z: 1.5932e+01, sindy-reg: 5.0306
# Epoch 32600
#   train loss: 3.2937e-04, decoder: 1.2804e-04, sindy-x: 1.9510e+00, sindy-z: 6.2279e-02, sindy-reg: 5.0299
# Epoch 32700
#   train loss: 3.5223e-04, decoder: 1.3196e-04, sindy-x: 1.9706e+00, sindy-z: 2.3207e-01, sindy-reg: 5.0321
# Epoch 32800
#   train loss: 3.2669e-04, decoder: 1.2758e-04, sindy-x: 1.9262e+00, sindy-z: 6.4925e-02, sindy-reg: 5.0322
# Epoch 32900
#   train loss: 3.2683e-04, decoder: 1.2667e-04, sindy-x: 1.9325e+00, sindy-z: 6.9170e-02, sindy-reg: 5.0326
# Epoch 33000
#   train loss: 3.2226e-04, decoder: 1.2482e-04, sindy-x: 1.9154e+00, sindy-z: 5.8986e-02, sindy-reg: 5.0332
# Epoch 33100
#   train loss: 3.3686e-04, decoder: 1.3202e-04, sindy-x: 1.9401e+00, sindy-z: 1.0832e-01, sindy-reg: 5.0335
# Epoch 33200
#   train loss: 3.2037e-04, decoder: 1.2396e-04, sindy-x: 1.9051e+00, sindy-z: 5.9095e-02, sindy-reg: 5.0344
# Epoch 33300
#   train loss: 9.1347e-04, decoder: 3.1902e-04, sindy-x: 2.2188e+00, sindy-z: 3.7257e+00, sindy-reg: 5.0279
# Epoch 33400
#   train loss: 3.2111e-04, decoder: 1.2432e-04, sindy-x: 1.9077e+00, sindy-z: 6.0216e-02, sindy-reg: 5.0337
# Epoch 33500
#   train loss: 3.1760e-04, decoder: 1.2268e-04, sindy-x: 1.8903e+00, sindy-z: 5.8916e-02, sindy-reg: 5.0347
# Epoch 33600
#   train loss: 3.1533e-04, decoder: 1.2193e-04, sindy-x: 1.8764e+00, sindy-z: 5.7636e-02, sindy-reg: 5.0350
# Epoch 33700
#   train loss: 3.9890e-04, decoder: 1.8428e-04, sindy-x: 1.9067e+00, sindy-z: 2.3955e-01, sindy-reg: 5.0367
# Epoch 33800
#   train loss: 3.1299e-04, decoder: 1.2123e-04, sindy-x: 1.8625e+00, sindy-z: 5.5096e-02, sindy-reg: 5.0352
# Epoch 33900
#   train loss: 3.2854e-04, decoder: 1.2187e-04, sindy-x: 1.8684e+00, sindy-z: 1.9832e-01, sindy-reg: 5.0356
# Epoch 34000
#   train loss: 3.3824e-04, decoder: 1.3359e-04, sindy-x: 1.8617e+00, sindy-z: 1.8483e-01, sindy-reg: 5.0355
# Epoch 34100
#   train loss: 4.5988e-04, decoder: 2.2909e-04, sindy-x: 1.9393e+00, sindy-z: 3.6854e-01, sindy-reg: 5.0325
# Epoch 34200
#   train loss: 3.1543e-04, decoder: 1.2184e-04, sindy-x: 1.8406e+00, sindy-z: 9.5257e-02, sindy-reg: 5.0358
# Epoch 34300
#   train loss: 3.1500e-04, decoder: 1.2131e-04, sindy-x: 1.8410e+00, sindy-z: 9.5861e-02, sindy-reg: 5.0367
# Epoch 34400
#   train loss: 3.1965e-04, decoder: 1.2813e-04, sindy-x: 1.8210e+00, sindy-z: 9.4204e-02, sindy-reg: 5.0374
# Epoch 34500
#   train loss: 3.0640e-04, decoder: 1.1910e-04, sindy-x: 1.8150e+00, sindy-z: 5.7976e-02, sindy-reg: 5.0365
# Epoch 34600
#   train loss: 3.2657e-04, decoder: 1.3012e-04, sindy-x: 1.8124e+00, sindy-z: 1.5213e-01, sindy-reg: 5.0360
# Epoch 34700
#   train loss: 3.7429e-03, decoder: 2.5836e-03, sindy-x: 3.5643e+00, sindy-z: 8.0283e+00, sindy-reg: 5.0372
# Epoch 34800
#   train loss: 3.0180e-04, decoder: 1.1656e-04, sindy-x: 1.7984e+00, sindy-z: 5.3996e-02, sindy-reg: 5.0374
# Epoch 34900
#   train loss: 7.6725e-04, decoder: 3.0979e-04, sindy-x: 2.0133e+00, sindy-z: 2.5613e+00, sindy-reg: 5.0352
# Epoch 35000
#   train loss: 2.9937e-04, decoder: 1.1549e-04, sindy-x: 1.7849e+00, sindy-z: 5.3888e-02, sindy-reg: 5.0373
# Epoch 35100
#   train loss: 3.2047e-04, decoder: 1.3124e-04, sindy-x: 1.7847e+00, sindy-z: 1.0765e-01, sindy-reg: 5.0374
# Epoch 35200
#   train loss: 5.4819e-04, decoder: 3.0273e-04, sindy-x: 1.8975e+00, sindy-z: 5.5709e-01, sindy-reg: 5.0389
# Epoch 35300
#   train loss: 3.5175e-04, decoder: 1.3524e-04, sindy-x: 1.8324e+00, sindy-z: 3.3265e-01, sindy-reg: 5.0379
# Epoch 35400
#   train loss: 1.0950e-03, decoder: 6.5932e-04, sindy-x: 2.4892e+00, sindy-z: 1.8679e+00, sindy-reg: 5.0382
# Epoch 35500
#   train loss: 2.9761e-04, decoder: 1.1550e-04, sindy-x: 1.7451e+00, sindy-z: 7.6056e-02, sindy-reg: 5.0394
# Epoch 35600
#   train loss: 4.8417e-04, decoder: 2.5341e-04, sindy-x: 1.8446e+00, sindy-z: 4.6296e-01, sindy-reg: 5.0399
# Epoch 35700
#   train loss: 3.3674e-04, decoder: 1.2008e-04, sindy-x: 1.7635e+00, sindy-z: 4.0313e-01, sindy-reg: 5.0390
# Epoch 35800
#   train loss: 3.3455e-04, decoder: 1.4262e-04, sindy-x: 1.7513e+00, sindy-z: 1.6805e-01, sindy-reg: 5.0379
# Epoch 35900
#   train loss: 5.1488e-04, decoder: 2.1245e-04, sindy-x: 1.8101e+00, sindy-z: 1.2142e+00, sindy-reg: 5.0398
# Epoch 36000
#   train loss: 3.6933e-04, decoder: 1.4723e-04, sindy-x: 1.8087e+00, sindy-z: 4.1225e-01, sindy-reg: 5.0395
# Epoch 36100
#   train loss: 3.4499e-04, decoder: 1.3550e-04, sindy-x: 1.7321e+00, sindy-z: 3.6273e-01, sindy-reg: 5.0396
# Epoch 36200
#   train loss: 3.1399e-04, decoder: 1.1287e-04, sindy-x: 1.7180e+00, sindy-z: 2.9322e-01, sindy-reg: 5.0388
# Epoch 36300
#   train loss: 2.8845e-04, decoder: 1.1218e-04, sindy-x: 1.6955e+00, sindy-z: 6.7184e-02, sindy-reg: 5.0411
# Epoch 36400
#   train loss: 3.2567e-04, decoder: 1.2788e-04, sindy-x: 1.7109e+00, sindy-z: 2.6691e-01, sindy-reg: 5.0382
# Epoch 36500
#   train loss: 3.4454e-04, decoder: 1.1251e-04, sindy-x: 1.7212e+00, sindy-z: 5.9918e-01, sindy-reg: 5.0407
# Epoch 36600
#   train loss: 3.1797e-04, decoder: 1.1730e-04, sindy-x: 1.6868e+00, sindy-z: 3.1989e-01, sindy-reg: 5.0419
# Epoch 36700
#   train loss: 2.8332e-04, decoder: 1.0949e-04, sindy-x: 1.6828e+00, sindy-z: 5.5539e-02, sindy-reg: 5.0397
# Epoch 36800
#   train loss: 2.8010e-04, decoder: 1.0776e-04, sindy-x: 1.6679e+00, sindy-z: 5.5519e-02, sindy-reg: 5.0417
# Epoch 36900
#   train loss: 4.3038e-04, decoder: 2.1394e-04, sindy-x: 1.7505e+00, sindy-z: 4.1385e-01, sindy-reg: 5.0415
# Epoch 37000
#   train loss: 3.4645e-04, decoder: 1.4732e-04, sindy-x: 1.7102e+00, sindy-z: 2.8111e-01, sindy-reg: 5.0416
# Epoch 37100
#   train loss: 6.9885e-04, decoder: 2.8200e-04, sindy-x: 1.8635e+00, sindy-z: 2.3050e+00, sindy-reg: 5.0415
# Epoch 37200
#   train loss: 3.1635e-04, decoder: 1.3613e-04, sindy-x: 1.6615e+00, sindy-z: 1.4065e-01, sindy-reg: 5.0422
# Epoch 37300
#   train loss: 2.8425e-04, decoder: 1.1180e-04, sindy-x: 1.6462e+00, sindy-z: 7.8358e-02, sindy-reg: 5.0422
# Epoch 37400
#   train loss: 2.5216e-03, decoder: 1.6685e-03, sindy-x: 3.5687e+00, sindy-z: 4.9632e+00, sindy-reg: 5.0429
# Epoch 37500
#   train loss: 2.7159e-04, decoder: 1.0441e-04, sindy-x: 1.6244e+00, sindy-z: 4.7413e-02, sindy-reg: 5.0427
# Epoch 37600
#   train loss: 2.8556e-04, decoder: 1.0728e-04, sindy-x: 1.6365e+00, sindy-z: 1.4633e-01, sindy-reg: 5.0417
# Epoch 37700
#   train loss: 3.8730e-04, decoder: 1.3686e-04, sindy-x: 1.6379e+00, sindy-z: 8.6649e-01, sindy-reg: 5.0431
# Epoch 37800
#   train loss: 1.0036e-03, decoder: 6.3203e-04, sindy-x: 1.9624e+00, sindy-z: 1.7532e+00, sindy-reg: 5.0426
# Epoch 37900
#   train loss: 7.4207e-04, decoder: 3.3870e-04, sindy-x: 2.0348e+00, sindy-z: 1.9989e+00, sindy-reg: 5.0425
# Epoch 38000
#   train loss: 3.8092e-03, decoder: 2.7386e-03, sindy-x: 4.4558e+00, sindy-z: 6.2502e+00, sindy-reg: 5.0432
# Epoch 38100
#   train loss: 5.1419e-04, decoder: 1.0956e-04, sindy-x: 1.6580e+00, sindy-z: 2.3883e+00, sindy-reg: 5.0428
# Epoch 38200
#   train loss: 2.6556e-04, decoder: 1.0180e-04, sindy-x: 1.5834e+00, sindy-z: 5.4199e-02, sindy-reg: 5.0441
# Epoch 38300
#   train loss: 2.6537e-04, decoder: 1.0234e-04, sindy-x: 1.5811e+00, sindy-z: 4.9249e-02, sindy-reg: 5.0432
# Epoch 38400
#   train loss: 2.9894e-04, decoder: 1.0936e-04, sindy-x: 1.5928e+00, sindy-z: 3.0300e-01, sindy-reg: 5.0448
# Epoch 38500
#   train loss: 2.7472e-04, decoder: 1.0565e-04, sindy-x: 1.5759e+00, sindy-z: 1.1472e-01, sindy-reg: 5.0419
# Epoch 38600
#   train loss: 2.7442e-04, decoder: 1.0513e-04, sindy-x: 1.6049e+00, sindy-z: 8.7937e-02, sindy-reg: 5.0441
# Epoch 38700
#   train loss: 4.8377e-04, decoder: 1.1764e-04, sindy-x: 1.6058e+00, sindy-z: 2.0556e+00, sindy-reg: 5.0449
# Epoch 38800
#   train loss: 7.4676e-04, decoder: 2.7290e-04, sindy-x: 1.9570e+00, sindy-z: 2.7816e+00, sindy-reg: 5.0450
# Epoch 38900
#   train loss: 6.6311e-04, decoder: 2.9731e-04, sindy-x: 1.7850e+00, sindy-z: 1.8730e+00, sindy-reg: 5.0448
# Epoch 39000
#   train loss: 2.5757e-04, decoder: 9.9029e-05, sindy-x: 1.5389e+00, sindy-z: 4.6544e-02, sindy-reg: 5.0450
# Epoch 39100
#   train loss: 7.7334e-04, decoder: 4.8929e-04, sindy-x: 1.8259e+00, sindy-z: 1.0146e+00, sindy-reg: 5.0463
# Epoch 39200
#   train loss: 3.5774e-04, decoder: 1.3887e-04, sindy-x: 1.6365e+00, sindy-z: 5.5217e-01, sindy-reg: 5.0448
# Epoch 39300
#   train loss: 3.0680e-04, decoder: 1.1953e-04, sindy-x: 1.6219e+00, sindy-z: 2.5083e-01, sindy-reg: 5.0440
# Epoch 39400
#   train loss: 2.6805e-04, decoder: 1.0263e-04, sindy-x: 1.5374e+00, sindy-z: 1.1671e-01, sindy-reg: 5.0461
# Epoch 39500
#   train loss: 7.9620e-04, decoder: 3.1737e-04, sindy-x: 1.9599e+00, sindy-z: 2.8284e+00, sindy-reg: 5.0448
# Epoch 39600
#   train loss: 1.0032e-03, decoder: 4.1423e-04, sindy-x: 2.1039e+00, sindy-z: 3.7854e+00, sindy-reg: 5.0461
# Epoch 39700
#   train loss: 5.0747e-04, decoder: 2.6966e-04, sindy-x: 1.7721e+00, sindy-z: 6.0602e-01, sindy-reg: 5.0465
# Epoch 39800
#   train loss: 2.6158e-04, decoder: 1.0221e-04, sindy-x: 1.4948e+00, sindy-z: 9.8908e-02, sindy-reg: 5.0462
# Epoch 39900
#   train loss: 2.4731e-04, decoder: 9.4848e-05, sindy-x: 1.4800e+00, sindy-z: 4.4600e-02, sindy-reg: 5.0459
# Epoch 40000
#   train loss: 2.5920e-04, decoder: 1.0177e-04, sindy-x: 1.4780e+00, sindy-z: 9.6335e-02, sindy-reg: 5.0457
# Epoch 40100
#   train loss: 6.5078e-04, decoder: 1.4904e-04, sindy-x: 1.5173e+00, sindy-z: 3.5001e+00, sindy-reg: 5.0434
# Epoch 40200
#   train loss: 2.4420e-04, decoder: 9.3138e-05, sindy-x: 1.4680e+00, sindy-z: 4.2642e-02, sindy-reg: 5.0455
# Epoch 40300
# ...
# Epoch 86800
#   train loss: 1.1759e-04, decoder: 5.3549e-05, sindy-x: 3.6527e-01, sindy-z: 2.7517e-01, sindy-reg: 5.2124
# Epoch 86900
#   train loss: 7.9068e-05, decoder: 3.8185e-05, sindy-x: 3.3485e-01, sindy-z: 7.3975e-02, sindy-reg: 5.2112
# Epoch 87000
#   train loss: 6.1585e-05, decoder: 2.4758e-05, sindy-x: 3.2199e-01, sindy-z: 4.6275e-02, sindy-reg: 5.2127
# Epoch 87100
#   train loss: 2.1481e-04, decoder: 5.2563e-05, sindy-x: 3.4779e-01, sindy-z: 1.2747e+00, sindy-reg: 5.2139
# Epoch 87200
#   train loss: 1.0659e-04, decoder: 2.3642e-05, sindy-x: 3.2793e-01, sindy-z: 5.0152e-01, sindy-reg: 5.2145
# Epoch 87300
#   train loss: 1.0730e-04, decoder: 4.4180e-05, sindy-x: 3.5198e-01, sindy-z: 2.7925e-01, sindy-reg: 5.2158
# Epoch 87400
#   train loss: 1.0695e-03, decoder: 7.3779e-04, sindy-x: 1.0618e+00, sindy-z: 2.2557e+00, sindy-reg: 5.2164
# Epoch 87500
#   train loss: 1.1933e-04, decoder: 4.0334e-05, sindy-x: 3.3860e-01, sindy-z: 4.5135e-01, sindy-reg: 5.2166
# Epoch 87600
#   train loss: 1.3717e-04, decoder: 5.3350e-05, sindy-x: 3.6845e-01, sindy-z: 4.6975e-01, sindy-reg: 5.2176
# Epoch 87700
#   train loss: 1.9285e-04, decoder: 9.3088e-05, sindy-x: 4.5385e-01, sindy-z: 5.4381e-01, sindy-reg: 5.2185
# Epoch 87800
#   train loss: 8.0197e-05, decoder: 3.3453e-05, sindy-x: 3.2206e-01, sindy-z: 1.4538e-01, sindy-reg: 5.2191
# Epoch 87900
#   train loss: 1.2020e-04, decoder: 4.0812e-05, sindy-x: 3.5807e-01, sindy-z: 4.3580e-01, sindy-reg: 5.2196
# Epoch 88000
#   train loss: 4.4727e-04, decoder: 2.1162e-04, sindy-x: 7.0148e-01, sindy-z: 1.6550e+00, sindy-reg: 5.2200
# Epoch 88100
#   train loss: 8.3008e-05, decoder: 2.4912e-05, sindy-x: 3.2574e-01, sindy-z: 2.5522e-01, sindy-reg: 5.2207
# Epoch 88200
#   train loss: 9.8793e-05, decoder: 4.3662e-05, sindy-x: 3.6595e-01, sindy-z: 1.8536e-01, sindy-reg: 5.2214
# Epoch 88300
#   train loss: 8.7401e-05, decoder: 3.1080e-05, sindy-x: 3.3169e-01, sindy-z: 2.3152e-01, sindy-reg: 5.2218
# Epoch 88400
#   train loss: 1.0197e-04, decoder: 4.1052e-05, sindy-x: 3.3263e-01, sindy-z: 2.7660e-01, sindy-reg: 5.2231
# Epoch 88500
#   train loss: 6.8322e-05, decoder: 2.3288e-05, sindy-x: 3.1467e-01, sindy-z: 1.3568e-01, sindy-reg: 5.2239
# Epoch 88600
#   train loss: 5.0420e-04, decoder: 2.1926e-04, sindy-x: 6.4691e-01, sindy-z: 2.2025e+00, sindy-reg: 5.2236
# Epoch 88700
#   train loss: 3.9414e-04, decoder: 2.5949e-04, sindy-x: 6.1095e-01, sindy-z: 7.3561e-01, sindy-reg: 5.2250
# Epoch 88800
#   train loss: 2.5209e-04, decoder: 1.1063e-04, sindy-x: 5.1688e-01, sindy-z: 8.9776e-01, sindy-reg: 5.2252
# Epoch 88900
#   train loss: 9.8857e-05, decoder: 4.9397e-05, sindy-x: 3.3130e-01, sindy-z: 1.6330e-01, sindy-reg: 5.2262
# Epoch 89000
#   train loss: 5.8593e-05, decoder: 2.1900e-05, sindy-x: 3.0924e-01, sindy-z: 5.7689e-02, sindy-reg: 5.2264
# Epoch 89100
#   train loss: 6.6722e-04, decoder: 4.3393e-04, sindy-x: 8.2607e-01, sindy-z: 1.5069e+00, sindy-reg: 5.2284
# Epoch 89200
#   train loss: 5.4632e-05, decoder: 2.1464e-05, sindy-x: 3.0466e-01, sindy-z: 2.7014e-02, sindy-reg: 5.2278
# Epoch 89300
#   train loss: 7.5083e-05, decoder: 3.1887e-05, sindy-x: 3.1903e-01, sindy-z: 1.1292e-01, sindy-reg: 5.2298
# Epoch 89400
#   train loss: 5.4725e-05, decoder: 2.1625e-05, sindy-x: 3.0357e-01, sindy-z: 2.7434e-02, sindy-reg: 5.2292
# Epoch 89500
#   train loss: 6.1449e-05, decoder: 2.5584e-05, sindy-x: 3.1145e-01, sindy-z: 4.7204e-02, sindy-reg: 5.2307
# Epoch 89600
#   train loss: 4.7672e-04, decoder: 1.9429e-04, sindy-x: 5.1095e-01, sindy-z: 2.3133e+00, sindy-reg: 5.2294
# Epoch 89700
#   train loss: 3.8765e-04, decoder: 2.1047e-04, sindy-x: 5.2115e-01, sindy-z: 1.2506e+00, sindy-reg: 5.2309
# Epoch 89800
#   train loss: 6.0518e-05, decoder: 2.5186e-05, sindy-x: 3.0632e-01, sindy-z: 4.7002e-02, sindy-reg: 5.2323
# Epoch 89900
#   train loss: 1.8941e-04, decoder: 7.5745e-05, sindy-x: 3.7496e-01, sindy-z: 7.6172e-01, sindy-reg: 5.2322
# Epoch 90000
#   train loss: 2.0290e-04, decoder: 5.4149e-05, sindy-x: 3.4084e-01, sindy-z: 1.1467e+00, sindy-reg: 5.2336
# Epoch 90100
#   train loss: 1.9454e-04, decoder: 5.2109e-05, sindy-x: 3.6195e-01, sindy-z: 1.0624e+00, sindy-reg: 5.2336
# Epoch 90200
#   train loss: 3.4655e-04, decoder: 1.3883e-04, sindy-x: 4.7759e-01, sindy-z: 1.5996e+00, sindy-reg: 5.2345
# Epoch 90300
#   train loss: 3.5836e-04, decoder: 1.4870e-04, sindy-x: 4.6091e-01, sindy-z: 1.6358e+00, sindy-reg: 5.2349
# Epoch 90400
#   train loss: 6.6306e-05, decoder: 2.3032e-05, sindy-x: 3.1042e-01, sindy-z: 1.2232e-01, sindy-reg: 5.2361
# Epoch 90500
#   train loss: 3.2033e-04, decoder: 1.5193e-04, sindy-x: 4.4802e-01, sindy-z: 1.2360e+00, sindy-reg: 5.2357
# Epoch 90600
#   train loss: 1.7149e-04, decoder: 3.0234e-05, sindy-x: 3.2372e-01, sindy-z: 1.0889e+00, sindy-reg: 5.2373
# Epoch 90700
#   train loss: 5.9386e-05, decoder: 2.2316e-05, sindy-x: 3.0506e-01, sindy-z: 6.5649e-02, sindy-reg: 5.2369
# Epoch 90800
#   train loss: 5.4744e-05, decoder: 2.1547e-05, sindy-x: 2.9870e-01, sindy-z: 3.3279e-02, sindy-reg: 5.2389
# Epoch 90900
#   train loss: 3.2658e-04, decoder: 1.4940e-04, sindy-x: 4.4453e-01, sindy-z: 1.3273e+00, sindy-reg: 5.2385
# Epoch 91000
#   train loss: 6.6323e-05, decoder: 2.3301e-05, sindy-x: 3.0147e-01, sindy-z: 1.2875e-01, sindy-reg: 5.2395
# Epoch 91100
#   train loss: 4.5759e-04, decoder: 2.3854e-04, sindy-x: 6.5895e-01, sindy-z: 1.5316e+00, sindy-reg: 5.2401
# Epoch 91200
#   train loss: 5.7713e-05, decoder: 2.2266e-05, sindy-x: 3.0079e-01, sindy-z: 5.3677e-02, sindy-reg: 5.2412
# Epoch 91300
#   train loss: 7.2306e-05, decoder: 3.1868e-05, sindy-x: 3.1140e-01, sindy-z: 9.2974e-02, sindy-reg: 5.2416
# Epoch 91400
#   train loss: 5.8091e-05, decoder: 2.2067e-05, sindy-x: 2.9733e-01, sindy-z: 6.2908e-02, sindy-reg: 5.2428
# Epoch 91500
#   train loss: 5.6576e-05, decoder: 2.2705e-05, sindy-x: 3.0110e-01, sindy-z: 3.7611e-02, sindy-reg: 5.2434
# Epoch 91600
#   train loss: 7.0743e-05, decoder: 2.7850e-05, sindy-x: 2.9927e-01, sindy-z: 1.2966e-01, sindy-reg: 5.2433
# Epoch 91700
#   train loss: 1.9548e-04, decoder: 1.0417e-04, sindy-x: 3.9451e-01, sindy-z: 5.1865e-01, sindy-reg: 5.2447
# Epoch 91800
#   train loss: 3.8788e-04, decoder: 2.6374e-04, sindy-x: 5.6769e-01, sindy-z: 6.7371e-01, sindy-reg: 5.2456
# Epoch 91900
#   train loss: 6.8252e-04, decoder: 3.2369e-04, sindy-x: 6.6005e-01, sindy-z: 2.9283e+00, sindy-reg: 5.2448
# Epoch 92000
#   train loss: 8.8900e-04, decoder: 3.3525e-04, sindy-x: 8.9579e-01, sindy-z: 4.6417e+00, sindy-reg: 5.2462
# Epoch 92100
#   train loss: 6.0335e-05, decoder: 2.5923e-05, sindy-x: 2.9592e-01, sindy-z: 4.8207e-02, sindy-reg: 5.2473
# Epoch 92200
#   train loss: 1.7582e-04, decoder: 8.4416e-05, sindy-x: 3.6746e-01, sindy-z: 5.4656e-01, sindy-reg: 5.2463
# Epoch 92300
#   train loss: 9.7659e-05, decoder: 2.1748e-05, sindy-x: 2.9861e-01, sindy-z: 4.6050e-01, sindy-reg: 5.2476
# Epoch 92400
#   train loss: 1.1560e-04, decoder: 4.7824e-05, sindy-x: 3.5847e-01, sindy-z: 3.1925e-01, sindy-reg: 5.2488
# Epoch 92500
#   train loss: 5.4738e-05, decoder: 2.1372e-05, sindy-x: 2.9255e-01, sindy-z: 4.1106e-02, sindy-reg: 5.2491
# Epoch 92600
#   train loss: 8.8476e-04, decoder: 5.1430e-04, sindy-x: 1.0244e+00, sindy-z: 2.6802e+00, sindy-reg: 5.2505
# Epoch 92700
#   train loss: 6.6996e-05, decoder: 2.8387e-05, sindy-x: 2.9686e-01, sindy-z: 8.9228e-02, sindy-reg: 5.2502
# Epoch 92800
#   train loss: 2.0378e-04, decoder: 6.7564e-05, sindy-x: 3.6005e-01, sindy-z: 1.0021e+00, sindy-reg: 5.2509
# Epoch 92900
#   train loss: 1.9004e-04, decoder: 2.8290e-05, sindy-x: 2.9604e-01, sindy-z: 1.3215e+00, sindy-reg: 5.2515
# Epoch 93000
#   train loss: 5.6349e-04, decoder: 3.7051e-04, sindy-x: 6.4809e-01, sindy-z: 1.2817e+00, sindy-reg: 5.2525
# Epoch 93100
#   train loss: 6.0202e-05, decoder: 2.4539e-05, sindy-x: 2.9731e-01, sindy-z: 5.9329e-02, sindy-reg: 5.2536
# Epoch 93200
#   train loss: 8.2102e-05, decoder: 4.0973e-05, sindy-x: 3.0465e-01, sindy-z: 1.0664e-01, sindy-reg: 5.2539
# Epoch 93300
#   train loss: 7.6200e-05, decoder: 3.2293e-05, sindy-x: 2.9799e-01, sindy-z: 1.4109e-01, sindy-reg: 5.2544
# Epoch 93400
#   train loss: 1.3578e-04, decoder: 7.5588e-05, sindy-x: 3.4635e-01, sindy-z: 2.5559e-01, sindy-reg: 5.2549
# Epoch 93500
#   train loss: 1.6058e-04, decoder: 8.3912e-05, sindy-x: 3.5605e-01, sindy-z: 4.1064e-01, sindy-reg: 5.2551
# Epoch 93600
#   train loss: 1.6364e-04, decoder: 9.8055e-05, sindy-x: 4.0475e-01, sindy-z: 2.5106e-01, sindy-reg: 5.2562
# Epoch 93700
#   train loss: 2.8279e-04, decoder: 1.5939e-04, sindy-x: 4.8399e-01, sindy-z: 7.5007e-01, sindy-reg: 5.2567
# Epoch 93800
#   train loss: 8.3901e-05, decoder: 2.6205e-05, sindy-x: 2.9621e-01, sindy-z: 2.8076e-01, sindy-reg: 5.2575
# Epoch 93900
#   train loss: 6.2787e-05, decoder: 2.4200e-05, sindy-x: 2.9554e-01, sindy-z: 9.0334e-02, sindy-reg: 5.2589
# Epoch 94000
#   train loss: 1.9840e-04, decoder: 1.0707e-04, sindy-x: 4.7834e-01, sindy-z: 4.3497e-01, sindy-reg: 5.2588
# Epoch 94100
#   train loss: 5.4043e-05, decoder: 2.1007e-05, sindy-x: 2.8846e-01, sindy-z: 4.1898e-02, sindy-reg: 5.2590
# Epoch 94200
#   train loss: 3.5390e-04, decoder: 2.0246e-04, sindy-x: 4.8459e-01, sindy-z: 1.0299e+00, sindy-reg: 5.2605
# Epoch 94300
#   train loss: 7.2271e-05, decoder: 3.1273e-05, sindy-x: 3.0636e-01, sindy-z: 1.0363e-01, sindy-reg: 5.2600
# Epoch 94400
#   train loss: 5.6254e-05, decoder: 2.0945e-05, sindy-x: 2.8602e-01, sindy-z: 6.7071e-02, sindy-reg: 5.2616
# Epoch 94500
#   train loss: 4.9908e-04, decoder: 3.1371e-04, sindy-x: 6.1198e-01, sindy-z: 1.2417e+00, sindy-reg: 5.2617
# Epoch 94600
#   train loss: 5.9049e-05, decoder: 2.1907e-05, sindy-x: 2.8618e-01, sindy-z: 8.5242e-02, sindy-reg: 5.2628
# Epoch 94700
#   train loss: 2.4465e-04, decoder: 1.6026e-04, sindy-x: 4.3529e-01, sindy-z: 4.0860e-01, sindy-reg: 5.2634
# Epoch 94800
#   train loss: 5.4443e-05, decoder: 2.2540e-05, sindy-x: 2.8382e-01, sindy-z: 3.5212e-02, sindy-reg: 5.2640
# Epoch 94900
#   train loss: 1.2103e-04, decoder: 6.1512e-05, sindy-x: 3.2600e-01, sindy-z: 2.6919e-01, sindy-reg: 5.2643
# Epoch 95000
#   train loss: 6.9839e-05, decoder: 3.0952e-05, sindy-x: 2.8938e-01, sindy-z: 9.9489e-02, sindy-reg: 5.2652
# Epoch 95100
#   train loss: 9.8189e-05, decoder: 4.6851e-05, sindy-x: 3.2102e-01, sindy-z: 1.9235e-01, sindy-reg: 5.2653
# Epoch 95200
#   train loss: 7.7581e-05, decoder: 2.6082e-05, sindy-x: 2.8658e-01, sindy-z: 2.2841e-01, sindy-reg: 5.2662
# Epoch 95300
#   train loss: 5.8921e-05, decoder: 2.3006e-05, sindy-x: 2.8686e-01, sindy-z: 7.2297e-02, sindy-reg: 5.2673
# Epoch 95400
#   train loss: 2.5840e-04, decoder: 8.0372e-05, sindy-x: 3.6023e-01, sindy-z: 1.4200e+00, sindy-reg: 5.2666
# Epoch 95500
#   train loss: 9.4075e-05, decoder: 4.2330e-05, sindy-x: 3.2538e-01, sindy-z: 1.9207e-01, sindy-reg: 5.2685
# Epoch 95600
#   train loss: 1.3821e-04, decoder: 4.9952e-05, sindy-x: 3.2486e-01, sindy-z: 5.5773e-01, sindy-reg: 5.2689
# Epoch 95700
#   train loss: 1.0645e-04, decoder: 4.1455e-05, sindy-x: 2.9193e-01, sindy-z: 3.5798e-01, sindy-reg: 5.2696
# Epoch 95800
#   train loss: 1.0702e-04, decoder: 2.6190e-05, sindy-x: 2.8862e-01, sindy-z: 5.1971e-01, sindy-reg: 5.2697
# Epoch 95900
#   train loss: 5.6478e-05, decoder: 2.1115e-05, sindy-x: 2.8245e-01, sindy-z: 7.1179e-02, sindy-reg: 5.2707
# Epoch 96000
#   train loss: 4.8013e-04, decoder: 3.0871e-04, sindy-x: 6.8208e-01, sindy-z: 1.0321e+00, sindy-reg: 5.2717
# Epoch 96100
#   train loss: 6.6446e-05, decoder: 2.8126e-05, sindy-x: 2.9388e-01, sindy-z: 8.9318e-02, sindy-reg: 5.2724
# Epoch 96200
#   train loss: 5.5576e-05, decoder: 2.1362e-05, sindy-x: 2.7917e-01, sindy-z: 6.2968e-02, sindy-reg: 5.2726
# Epoch 96300
#   train loss: 9.1813e-05, decoder: 4.3966e-05, sindy-x: 3.0400e-01, sindy-z: 1.7447e-01, sindy-reg: 5.2730
# Epoch 96400
#   train loss: 6.3868e-04, decoder: 4.2537e-04, sindy-x: 7.4988e-01, sindy-z: 1.3832e+00, sindy-reg: 5.2745
# Epoch 96500
#   train loss: 1.1434e-04, decoder: 4.9975e-05, sindy-x: 3.3874e-01, sindy-z: 3.0487e-01, sindy-reg: 5.2747
# Epoch 96600
#   train loss: 1.4555e-04, decoder: 6.4963e-05, sindy-x: 3.4143e-01, sindy-z: 4.6443e-01, sindy-reg: 5.2755
# Epoch 96700
#   train loss: 6.9652e-05, decoder: 2.3587e-05, sindy-x: 2.7968e-01, sindy-z: 1.8098e-01, sindy-reg: 5.2758
# Epoch 96800
#   train loss: 1.0014e-04, decoder: 4.4954e-05, sindy-x: 3.1122e-01, sindy-z: 2.4063e-01, sindy-reg: 5.2768
# Epoch 96900
#   train loss: 5.4801e-04, decoder: 2.8177e-04, sindy-x: 5.4007e-01, sindy-z: 2.1224e+00, sindy-reg: 5.2765
# Epoch 97000
#   train loss: 2.5983e-04, decoder: 1.4879e-04, sindy-x: 3.9858e-01, sindy-z: 7.1178e-01, sindy-reg: 5.2778
# Epoch 97100
#   train loss: 1.3341e-04, decoder: 6.2851e-05, sindy-x: 3.4790e-01, sindy-z: 3.5772e-01, sindy-reg: 5.2778
# Epoch 97200
#   train loss: 6.2433e-05, decoder: 2.3086e-05, sindy-x: 2.7224e-01, sindy-z: 1.2123e-01, sindy-reg: 5.2791
# Epoch 97300
#   train loss: 7.5448e-05, decoder: 2.7808e-05, sindy-x: 2.8961e-01, sindy-z: 1.8678e-01, sindy-reg: 5.2798
# Epoch 97400
#   train loss: 1.3998e-04, decoder: 7.1119e-05, sindy-x: 3.5488e-01, sindy-z: 3.3373e-01, sindy-reg: 5.2792
# Epoch 97500
#   train loss: 1.8678e-04, decoder: 6.1376e-05, sindy-x: 3.2808e-01, sindy-z: 9.2601e-01, sindy-reg: 5.2805
# Epoch 97600
#   train loss: 1.1642e-04, decoder: 5.6936e-05, sindy-x: 3.0577e-01, sindy-z: 2.8908e-01, sindy-reg: 5.2814
# Epoch 97700
#   train loss: 6.1268e-05, decoder: 2.6767e-05, sindy-x: 2.8078e-01, sindy-z: 6.4232e-02, sindy-reg: 5.2829
# Epoch 97800
#   train loss: 1.1870e-04, decoder: 5.1029e-05, sindy-x: 3.2329e-01, sindy-z: 3.5346e-01, sindy-reg: 5.2829
# Epoch 97900
#   train loss: 1.2249e-04, decoder: 3.4430e-05, sindy-x: 3.0099e-01, sindy-z: 5.7963e-01, sindy-reg: 5.2824
# Epoch 98000
#   train loss: 4.8914e-05, decoder: 1.9413e-05, sindy-x: 2.6730e-01, sindy-z: 2.7712e-02, sindy-reg: 5.2839
# Epoch 98100
#   train loss: 4.9412e-05, decoder: 1.9531e-05, sindy-x: 2.6813e-01, sindy-z: 3.0684e-02, sindy-reg: 5.2845
# Epoch 98200
#   train loss: 4.9504e-05, decoder: 1.9246e-05, sindy-x: 2.6829e-01, sindy-z: 3.4292e-02, sindy-reg: 5.2856
# Epoch 98300
#   train loss: 5.3047e-05, decoder: 2.0505e-05, sindy-x: 2.7082e-01, sindy-z: 5.4596e-02, sindy-reg: 5.2849
# Epoch 98400
#   train loss: 6.1308e-05, decoder: 2.1215e-05, sindy-x: 2.8411e-01, sindy-z: 1.1682e-01, sindy-reg: 5.2858
# Epoch 98500
#   train loss: 3.4910e-04, decoder: 1.3808e-04, sindy-x: 4.8743e-01, sindy-z: 1.6228e+00, sindy-reg: 5.2870
# Epoch 98600
#   train loss: 8.1050e-05, decoder: 2.1115e-05, sindy-x: 2.7372e-01, sindy-z: 3.2563e-01, sindy-reg: 5.2875
# Epoch 98700
#   train loss: 3.0361e-04, decoder: 1.2991e-04, sindy-x: 4.9305e-01, sindy-z: 1.2440e+00, sindy-reg: 5.2885
# Epoch 98800
#   train loss: 1.3125e-04, decoder: 2.9529e-05, sindy-x: 2.7589e-01, sindy-z: 7.4129e-01, sindy-reg: 5.2891
# Epoch 98900
#   train loss: 6.9053e-04, decoder: 4.9153e-04, sindy-x: 5.4806e-01, sindy-z: 1.4420e+00, sindy-reg: 5.2886
# Epoch 99000
#   train loss: 5.6953e-05, decoder: 1.9385e-05, sindy-x: 2.6786e-01, sindy-z: 1.0782e-01, sindy-reg: 5.2894
# Epoch 99100
#   train loss: 7.7303e-05, decoder: 2.6278e-05, sindy-x: 2.7983e-01, sindy-z: 2.3042e-01, sindy-reg: 5.2904
# Epoch 99200
#   train loss: 3.8697e-04, decoder: 2.4459e-04, sindy-x: 5.8414e-01, sindy-z: 8.3968e-01, sindy-reg: 5.2917
# Epoch 99300
#   train loss: 8.2066e-05, decoder: 2.9202e-05, sindy-x: 2.8344e-01, sindy-z: 2.4521e-01, sindy-reg: 5.2916
# Epoch 99400
#   train loss: 9.1394e-05, decoder: 4.5028e-05, sindy-x: 3.0814e-01, sindy-z: 1.5553e-01, sindy-reg: 5.2925
# Epoch 99500
#   train loss: 5.2580e-05, decoder: 1.9119e-05, sindy-x: 2.6438e-01, sindy-z: 7.0228e-02, sindy-reg: 5.2932
# Epoch 99600
#   train loss: 6.0470e-05, decoder: 2.7887e-05, sindy-x: 2.7671e-01, sindy-z: 4.9119e-02, sindy-reg: 5.2933
# Epoch 99700
#   train loss: 5.1972e-05, decoder: 1.9168e-05, sindy-x: 2.5983e-01, sindy-z: 6.8209e-02, sindy-reg: 5.2944
# Epoch 99800
#   train loss: 5.3941e-05, decoder: 2.2423e-05, sindy-x: 2.6646e-01, sindy-z: 4.8717e-02, sindy-reg: 5.2949
# Epoch 99900
#   train loss: 1.1456e-04, decoder: 5.9667e-05, sindy-x: 3.0770e-01, sindy-z: 2.4123e-01, sindy-reg: 5.2951
# * Evaluating
#   Time: 0.00 s, Case: [4.44 1.  ], Tol: 0.00100, Max Error: -1.000000
#   Max rel. err.: 2.1%, Update tolerance for error indicator from 0.00100 to 0.17382
#   PARAMETERS EXIST, NOT adding it!
#   Max error indicator <= Tol! Current subset ratio 50.0%
# training time: 41.09 mins

# %%
# history of validation loss
train_loss = np.array(df['training_losses'][0]).squeeze()
test_loss = np.array(df['testing_losses'][0]).squeeze()

fig, ax1 = plt.subplots(figsize=(9,5))
xt = np.linspace(1,df['num_epochs'][0],train_loss.shape[0])
ax1.plot(xt, train_loss[:,0], 'r', label='Train')
ax1.set_yscale('log')
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
ax1.set_xlabel('Epochs', fontsize=16)
ax1.set_ylabel('Loss', color='r', fontsize=16)
ax1.set_xlim(0, df['num_epochs'][0])
ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
xt = np.linspace(1,df['num_epochs'],test_loss.shape[0])
ax2.plot(xt, test_loss, 'b-o', label='Val')
ax2.set_ylabel('Max Error', color='b', fontsize=16)
ax2.tick_params(axis='both', labelsize=16)
ax2.tick_params(axis='y', labelcolor='b')

plt.grid()
plt.tight_layout()
plt.savefig(f"{params['fig_path']}/loss.png")
